# %%
import pdfplumber
import re
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch
import random
import spacy
import language_tool_python
import csv

# %% [markdown]
# # Preprocessing the Given PDF

# %%
import pdfplumber
import re
import csv

def preprocess_text(text):
    text = text.replace('\n', ' ')
    text = re.sub(r'[^a-zA-Z0-9\s.]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    text = text.lower()
    return text

def extract_and_preprocess_text(file_path):
    preprocessed_texts = [] 
    with pdfplumber.open(file_path) as pdf:
        num_pages = len(pdf.pages)

        for page_num in range(num_pages):
            page = pdf.pages[page_num]
            text = page.extract_text()
            preprocessed_text = preprocess_text(text)
            preprocessed_texts.append(preprocessed_text)

            print(f"Page {page_num + 1}: {preprocessed_text}\n")

    return preprocessed_texts 

def save_to_csv(file_path, preprocessed_texts):
    with open(file_path, 'w', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(['Page', 'Preprocessed Text'])  # Header

        for i, text in enumerate(preprocessed_texts, start=1):
            csv_writer.writerow([i, text])

pdf_file_path = 'C:/Users/sriyo/Desktop/jets/NLP Bot/files/NCERT Biology.pdf'
csv_file_path = 'output.csv'

preprocessed_texts = extract_and_preprocess_text(pdf_file_path)
save_to_csv(csv_file_path, preprocessed_texts)
# Out:
# Page 1: chapter 2 human reproduction 2.1 the male reproductive system as you are aware humans are sexually reproducing and 2.2 the female reproductive viviparous. the reproductive events in humans include system formation of gametes gametogenesis i.e. sperms in males 2.3 gametogenesis and ovum in females transfer of sperms into the female 2.4 menstrual cycle genital tract insemination and fusion of male and female gametes fertilisation leading to formation of zygote. this 2.5 fertilisation and is followed by formation and development of blastocyst implantation and its attachment to the uterine wall implantation 2.6 pregnancy and embryonic embryonic development gestation and delivery of the development baby parturition. you have learnt that these reproductive events occur after puberty. there are remarkable 2.7 parturition and lactation differences between the reproductive events in the male and in the female for example sperm formation continues even in old men but formation of ovum ceases in women around the age of fifty years. let us examine the male and female reproductive systems in human. 2.1 t m r s he ale eproductive ystem the male reproductive system is located in the pelvis region figure 2.1a. it includes a pair of testes alongwith accessory ducts glands and the external genitalia. rationalised 202324
#
# Page 2: human reproduction the testes are situated outside the abdominal cavity within a pouch called scrotum. the scrotum helps in maintaining the low temperature of the testes 22.5o c lower than the normal internal body temperature necessary for spermatogenesis. in adults each testis is oval in shape with a length of about 4 to 5 cm and a width of about 2 to 3 cm. the testis is covered by a dense covering. each testis has about 250 compartments called testicular lobules figure 2.1a diagrammatic sectional view of male pelvis figure 2.1b. showing reproductive system each lobule contains one to three highly coiled seminiferous tubules in which sperms are produced. each seminiferous tubule is lined on its inside by two types of cells called male germ cells spermatogonia and sertoli cells figure 2.2 . the male germ cells undergo meiotic divisions finally leading to sperm formation while sertoli cells provide nutrition to the germ cells. the regions outside the seminiferous tubules called interstitial spaces contain small blood vessels and interstitial cells or leydig cells figure 2.2. leydig cells synthesise and secrete testicular hormones called figure 2.1b diagrammatic view of male reproductive system part of testis is open to show inner details androgens. other immunologically competent cells are also present. the male sex accessory ducts include rete testis vasa efferentia epididymis and vas deferens figure 2.1b. the seminiferous tubules of the testis open into the vasa efferentia through rete testis. the vasa efferentia leave the testis and open into epididymis located along the posterior surface 27 of each testis. the epididymis leads to vas deferens that ascends to the abdomen and loops over the urinary bladder. it receives a duct from seminal vesicle and opens into urethra as the ejaculatory duct figure 2.1a. these ducts store and transport the sperms from the testis to the outside through urethra. the urethra originates from the urinary bladder and extends through the penis to its external opening called urethral meatus. rationalised 202324
#
# Page 3: biology figure 2.2 diagrammatic sectional view of seminiferous tubule the penis is the male external genitalia figure 2.1a b. it is made up of special tissue that helps in erection of the penis to facilitate insemination. the enlarged end of penis called the glans penis is covered by a loose fold of skin called foreskin. the male accessory glands figure 2.1a b include paired seminal vesicles a prostate and paired bulbourethral glands. secretions of these glands constitute the seminal plasma which is rich in fructose calcium and certain enzymes. the secretions of bulbourethral glands also helps in the lubrication of the penis. 2.2 t f r s he emale eproductive ystem the female reproductive system consists of a pair of ovaries alongwith a pair of oviducts uterus cervix vagina and the external genitalia located in pelvic region figure 2.3a. these parts of the system alongwith a pair of the mammary glands are integrated structurally and functionally to support the processes of ovulation fertilisation pregnancy birth and child care. ovaries are the primary female sex organs that produce the female 28 gamete ovum and several steroid hormones ovarian hormones. the ovaries are located one on each side of the lower abdomen figure 2.3b. each ovary is about 2 to 4 cm in length and is connected to the pelvic wall and uterus by ligaments. each ovary is covered by a thin epithelium which encloses the ovarian stroma. the stroma is divided into two zones a peripheral cortex and an inner medulla. rationalised 202324
#
# Page 4: human reproduction figure 2.3 a diagrammatic sectional view of female pelvis showing reproductive system the oviducts fallopian tubes uterus and vagina constitute the female accessory ducts. each fallopian tube is about 1012 cm long and extends from the periphery of each ovary to the uterus figure 2.3b the part closer to the ovary is the funnelshaped infundibulum. the edges of the infundibulum possess fingerlike projections called fimbriae which help in collection of the ovum after ovulation. the infundibulum leads to a wider 29 figure 2.3 b diagrammatic sectional view of the female reproductive system rationalised 202324
#
# Page 5: biology part of the oviduct called ampulla. the last part of the oviduct isthmus has a narrow lumen and it joins the uterus. the uterus is single and it is also called womb. the shape of the uterus is like an inverted pear. it is supported by ligaments attached to the pelvic wall. the uterus opens into vagina through a narrow cervix. the cavity of the cervix is called cervical canal figure 2.3b which alongwith vagina forms the birth canal. the wall of the uterus has three layers of tissue. the external thin membranous perimetrium middle thick layer of smooth muscle myometrium and inner glandular layer called endometrium that lines the uterine cavity. the endometrium undergoes cyclical changes during menstrual cycle while the myometrium exhibits strong contraction during delivery of the baby. the female external genitalia include mons pubis labia majora labia minora hymen and clitoris figure 2.3a. mons pubis is a cushion of fatty tissue covered by skin and pubic hair. the labia majora are fleshy folds of tissue which extend down from the mons pubis and surround the vaginal opening. the labia minora are paired folds of tissue under the labia majora. the opening of the vagina is often covered partially by a membrane called hymen. the clitoris is a tiny fingerlike structure which lies at the upper junction of the two labia minora above the urethral opening. the hymen is often torn during the first coitus intercourse. however it can also be broken by a sudden fall or jolt insertion of a vaginal tampon active participation in some sports like horseback riding cycling etc. in some women the hymen persists even after coitus. in fact the presence or absence of hymen is not a reliable indicator of virginity or sexual experience. 30 figure 2.4 a diagrammatic sectional view of mammary gland rationalised 202324
#
# Page 6: human reproduction a functional mammary gland is characteristic of all female mammals. the mammary glands are paired structures breasts that contain glandular tissue and variable amount of fat. the glandular tissue of each breast is divided into 1520 mammary lobes containing clusters of cells called alveoli figure 2.4. the cells of alveoli secrete milk which is stored in the cavities lumens of alveoli. the alveoli open into mammary tubules. the tubules of each lobe join to form a mammary duct. several mammary ducts join to form a wider mammary ampulla which is connected to lactiferous duct through which milk is sucked out. 2.3 g ametogenesis the primary sex organs the testis in the males and the ovaries in the femalesproduce gametes i.e sperms and ovum respectively by the process called gametogenesis. in testis the immature male germ cells spermatogonia produce sperms by spermatogenesis that begins at puberty. the spermatogonia sing. spermatogonium present on the inside wall of seminiferous tubules multiply by mitotic division and increase in numbers. each spermatogonium is diploid and contains 46 chromosomes. some of the spermatogonia called primary spermatocytes periodically undergo meiosis. a primary spermatocyte completes the first meiotic division reduction division leading to formation of two equal haploid cells called secondary spermatocytes which have only 23 chromosomes each. the secondary spermatocytes undergo the second meiotic division to produce four equal haploid spermatids figure 2.5. what would be the number of chromosome in the spermatids the spermatids are transformed into spermatozoa sperms by the process called spermiogenesis. after spermiogenesis sperm heads become embedded in the sertoli cells and are finally released from the seminiferous tubules by the process called spermiation. spermatogenesis starts at the age of figure 2.5 diagrammatic sectional view of a puberty due to significant increase in the seminiferous tubule enlarged secretion of gonadotropin releasing hormone 31 gnrh. this if you recall is a hypothalamic hormone. the increased levels of gnrh then acts at the anterior pituitary gland and stimulates secretion of two gonadotropins luteinising hormone lh and follicle stimulating hormone fsh. lh acts at the leydig cells and stimulates synthesis and secretion of androgens. androgens in turn stimulate the process of spermatogenesis. fsh acts on the sertoli cells and stimulates rationalised 202324
#
# Page 7: biology secretion of some factors which help in the process of spermiogenesis. let us examine the structure of a sperm. it is a microscopic structure composed of a head neck a middle piece and a tail figure 2.6. a plasma membrane envelops the whole body of sperm. the sperm head contains an elongated haploid nucleus the anterior portion of which is covered by a caplike structure acrosome. the acrosome is filled with enzymes that help fertilisation of the ovum. the middle piece possesses numerous mitochondria which produce energy for the movement of tail that facilitate sperm motility essential for fertilisation. the human male ejaculates about 200 to 300 million sperms during a coitus of which for normal fertility at least 60 per cent sperms must have normal shape and size and at least 40 per cent of them must show vigorous motility. sperms released from the seminiferous figure 2.6 structure of a sperm tubules are transported by the accessory ducts. secretions of epididymis vas deferens seminal vesicle and prostate are essential for maturation and motility of sperms. the seminal plasma along with the sperms constitute the semen. the functions of male sex accessory ducts and glands are maintained by the testicular hormones androgens. the process of formation of a mature female gamete is called oogenesis which is markedly different from spermatogenesis. oogenesis is initiated during the embryonic development stage when a couple of million gamete mother cells oogonia are formed within each fetal ovary no more oogonia are formed and added after birth. these cells start division and enter into prophasei of the meiotic division and get temporarily arrested at that stage called primary oocytes. each primary oocyte then gets surrounded by a layer of granulosa cells and is called the primary follicle figure 2.7. a large number of these follicles degenerate during the phase from birth to puberty. therefore at puberty only 6000080000 primary follicles are left in each ovary. the primary follicles get surrounded by more layers of granulosa cells and a new theca and are called secondary follicles. 32 the secondary follicle soon transforms into a tertiary follicle which is characterised by a fluid filled cavity called antrum. the theca layer is organised into an inner theca interna and an outer theca externa. it is important to draw your attention that it is at this stage that the primary oocyte within the tertiary follicle grows in size and completes its first meiotic division. it is an unequal division resulting in the formation of a large haploid secondary oocyte and a tiny first polar body figure 2.8b. the rationalised 202324
#
# Page 8: human reproduction secondary oocyte retains bulk of the nutrient rich cytoplasm of the primary oocyte. can you think of any advantage for this does the first polar body born out of first meiotic division divide further or degenerate at present we are not very certain about this. the tertiary follicle further changes into the mature follicle or graafian follicle figure 2.7. the secondary oocyte forms a new membrane called zona pellucida surrounding it. the graafian follicle now ruptures to release the secondary oocyte ovum from the ovary by the process called ovulation. can you figure 2.7 diagrammatic section view of ovary identify major differences between spermatogenesis and oogenesis a diagrammatic representation of spermatogenesis and oogenesis is given below figure 2.8. a b figure 2.8 schematic representation of a spermatogenesis b oogenesis 2.4 m c enstrual ycle 33 the reproductive cycle in the female primates e.g. monkeys apes and human beings is called menstrual cycle. the first menstruation begins at puberty and is called menarche. in human females menstruation is repeated at an average interval of about 2829 days and the cycle of events starting from one menstruation till the next one is called the menstrual cycle. one ovum is released ovulation during the middle rationalised 202324
#
# Page 9: biology figure 2.9 diagrammatic presentation of various events during a menstrual cycle of each menstrual cycle. the major events of the menstrual cycle are shown in figure 2.9. the cycle starts with the menstrual phase when menstrual flow occurs and it lasts for 35 days. the menstrual flow results due to breakdown of endometrial lining of the uterus and its blood vessels which forms liquid that comes out through vagina. menstruation only occurs if the released ovum is not fertilised. lack of menstruation may be indicative of pregnancy. however it may also be 34 caused due to some other underlying causes like stress poor health etc. the menstrual phase is followed by the follicular phase. during this phase the primary follicles in the ovary grow to become a fully mature graafian follicle and simultaneously the endometrium of uterus regenerates through proliferation. these changes in the ovary and the uterus are induced by changes in the levels of pituitary and ovarian hormones figure 2.9. the secretion of rationalised 202324
#
# Page 10: human reproduction gonadotropins lh and fsh increases gradually during the follicular menstrual hygiene phase and stimulates follicular development as well as secretion of estrogens by the growing follicles. both lh and fsh attain a peak level maintenance of in the middle of cycle about 14th day. rapid secretion of lh leading to hygiene and sanitation during menstruation is its maximum level during the midcycle called lh surge induces rupture very important. take of graafian follicle and thereby the release of ovum ovulation. the bath and clean yourself ovulation ovulatory phase is followed by the luteal phase during which regulary. use sanitary napkins or clean the remaining parts of the graafian follicle transform as the corpus homemade pads. luteum figure 2.9. the corpus luteum secretes large amounts of change sanitary progesterone which is essential for maintenance of the endometrium. napkins or homemade such an endometrium is necessary for implantation of the fertilised pads after every 45 hrs as per the requirement. ovum and other events of pregnancy. during pregnancy all events of dispose of the used the menstrual cycle stop and there is no menstruation. in the absence sanitary napkins of fertilisation the corpus luteum degenerates. this causes disintegration properly wrapping it with a used paper. do of the endometrium leading to menstruation marking a new cycle. in not throw the used human beings menstrual cycles ceases around 50 years of age that is napkins in the termed as menopause. cyclic menstruation is an indicator of normal drainpipe of toilets or reproductive phase and extends between menarche and menopause. in the open area. after handling the napkin wash hands with soap. 2.5 fertilisation and implantation during copulation coitus semen is released by the penis into the vagina insemination. the motile sperms swim rapidly pass through the cervix enter into the uterus and finally reach the ampullary region of the fallopian tube figure 2.11b. the ovum released by the ovary is also transported to the ampullary region where fertilisation takes place. fertilisation can only occur if the ovum and sperms are transported simultaneously to the ampullary region. this is the reason why not all copulations lead to fertilisation and pregnancy. the process of fusion of a sperm with an ovum is called fertilisation. during fertilisation a sperm comes in contact with the zona pellucida layer of the ovum figure 2.10 and induces changes in the membrane that block the entry of additional sperms. thus 35 35 it ensures that only one sperm can fertilise an ovum. the secretions of the acrosome help the sperm enter into the cytoplasm of the ovum through the zona pellucida and the plasma figure 2.10 ovum surrounded by few sperms rationalised 202324
#
# Page 11: biology membrane. this induces the completion of the meiotic division of the secondary oocyte. the second meiotic division is also unequal and results in the formation of a second polar body and a haploid ovum ootid. soon the haploid nucleus of the sperms and that of the ovum fuse together to form a diploid zygote. how many chromosomes will be there in the zygote one has to remember that the sex of the baby has been decided at this stage itself. let us see how as you know the chromosome pattern in the human female is xx and that in the male is xy. therefore all the haploid gametes ova produced by the female have the sex chromosome x whereas in the male gametes sperms the sex chromosome could be either x or y hence 50 per cent of sperms carry the x chromosome while the other 50 per cent carry the y. after fusion of the male and female gametes the zygote would carry either xx or xy depending on whether the sperm carrying x or y fertilised the ovum. the zygote carrying xx would develop into a female baby and xy would form a male you will learn more about the chromosomal patterns in chapter 5. that is why scientifically it is correct to say that the sex of the baby is determined by the father and not by the mother the mitotic division starts as the zygote moves through the isthmus of the oviduct called cleavage towards the uterus figure 2.11 and forms 2 4 8 16 daughter cells called blastomeres. the embryo with 8 to 16 36 figure 2.11 transport of ovum fertilisation and passage of growing embryo through fallopian tube rationalised 202324
#
# Page 12: human reproduction blastomeres is called a morula figure 2.11e. the morula continues to divide and transforms into blastocyst figure 2.11g as it moves further into the uterus. the blastomeres in the blastocyst are arranged into an outer layer called trophoblast and an inner group of cells attached to trophoblast called the inner cell mass. the trophoblast layer then gets attached to the endometrium and the inner cell mass gets differentiated as the embryo. after attachment the uterine cells divide rapidly and covers the blastocyst. as a result the blastocyst becomes embedded in the endometrium of the uterus figure 2.11 step h. this is called implantation and it leads to pregnancy. 2.6 p e d regnancy and mbryonic evelopment after implantation fingerlike projections appear on the trophoblast called chorionic villi which are surrounded by the uterine tissue and maternal blood. the chorionic villi and uterine tissue become interdigitated with each other and jointly form a structural and functional unit between developing embryo foetus and maternal body called placenta figure 2.12. the placenta facilitate the supply of oxygen and nutrients to the embryo and also removal of carbon dioxide and excretorywaste materials produced by the embryo. the placenta is connected to the embryo through an umbilical cord which helps in the transport of substances to and from the embryo. placenta also acts as an endocrine tissue and produces several hormones like human chorionic gonadotropin hcg human placental lactogen hpl estrogens progestogens etc. in the later phase of pregnancy a hormone called relaxin is also secreted by the ovary. let us remember that hcg hpl and relaxin are produced in women only during pregnancy. in addition during pregnancy the levels of other hormones like estrogens progestogens cortisol prolactin thyroxine etc. are increased several folds in the maternal blood. increased production of these hormones is essential for supporting the fetal growth 37 metabolic changes in the mother and maintenance of pregnancy. immediately after implantation the inner cell mass embryo differentiates figure 2.12 the human foetus within the uterus rationalised 202324
#
# Page 13: biology into an outer layer called ectoderm and an inner layer called endoderm. a mesoderm soon appears between the ectoderm and the endoderm. these three layers give rise to all tissues organs in adults. it needs to be mentioned here that the inner cell mass contains certain cells called stem cells which have the potency to give rise to all the tissues and organs. what are the major features of embryonic development at various months of pregnancy the human pregnancy lasts 9 months. do you know for how many months pregnancy last in dogs elephants cats find out. in human beings after one month of pregnancy the embryos heart is formed. the first sign of growing foetus may be noticed by listening to the heart sound carefully through the stethoscope. by the end of the second month of pregnancy the foetus develops limbs and digits. by the end of 12 weeks first trimester most of the major organ systems are formed for example the limbs and external genital organs are well developed. the first movements of the foetus and appearance of hair on the head are usually observed during the fifth month. by the end of about 24 weeks end of second trimester the body is covered with fine hair eyelids separate and eyelashes are formed. by the end of nine months of pregnancy the foetus is fully developed and is ready for delivery. 2.7 parturition and lactation the average duration of human pregnancy is about 9 months which is called the gestation period. vigorous contraction of the uterus at the end of pregnancy causes expulsiondelivery of the foetus. this process of delivery of the foetus childbirth is called parturition. parturition is induced by a complex neuroendocrine mechanism. the signals for parturition originate from the fully developed foetus and the placenta which induce mild uterine contractions called foetal ejection reflex. this triggers release of oxytocin from the maternal pituitary. oxytocin acts on the uterine muscle and causes stronger uterine contractions which in turn stimulates further secretion of oxytocin. the stimulatory reflex between the uterine contraction and oxytocin secretion continues resulting in stronger and stronger contractions. this leads to expulsion of the baby out of the uterus through the birth canal parturition. soon after the infant is delivered the placenta is also expelled out of the uterus. what do you think the doctors inject to induce delivery the mammary glands of the female undergo differentiation during pregnancy and starts producing milk towards the end of pregnancy by 38 the process called lactation. this helps the mother in feeding the new born. the milk produced during the initial few days of lactation is called colostrum which contains several antibodies absolutely essential to develop resistance for the newborn babies. breastfeeding during the initial period of infant growth is recommended by doctors for bringing up a healthy baby. rationalised 202324
#
# Page 14: human reproduction summary humans are sexually reproducing and viviparous. the male reproductive system is composed of a pair of testes the male sex accessory ducts and the accessory glands and external genitalia. each testis has about 250 compartments called testicular lobules and each lobule contains one to three highly coiled seminiferous tubules. each seminiferous tubule is lined inside by spermatogonia and sertoli cells. the spermatogonia undergo meiotic divisions leading to sperm formation while sertoli cells provide nutrition to the dividing germ cells. the leydig cells outside the seminiferous tubules synthesise and secrete testicular hormones called androgens. the male external genitalia is called penis. the female reproductive system consists of a pair of ovaries a pair of oviducts a uterus a vagina external genitalia and a pair of mammary glands. the ovaries produce the female gamete ovum and some steroid hormones ovarian hormones. ovarian follicles in different stages of development are embedded in the stroma. the oviducts uterus and vagina are female accessory ducts. the uterus has three layers namely perimetrium myometrium and endometrium. the female external genitalia includes mons pubis labia majora labia minora hymen and clitoris. the mammary glands are one of the female secondary sexual characteristics. spermatogenesis results in the formation of sperms that are transported by the male sex accessory ducts. a normal human sperm is composed of a head neck a middle piece and tail. the process of formation of mature female gametes is called oogenesis. the reproductive cycle of female primates is called menstrual cycle. menstrual cycle starts only after attaining sexual maturation puberty. during ovulation only one ovum is released per menstrual cycle. the cyclical changes in the ovary and the uterus during menstrual cycle are induced by changes in the levels of pituitary and ovarian hormones. after coitus sperms are transported to the ampulla where the sperm fertilises the ovum leading to formation of a diploid zygote. the presence of x or y chromosome in the sperm determines the sex of the embryo. the zygote undergoes repeated mitotic division to form a blastocyst which is implanted in the uterus resulting in pregnancy. after nine months of pregnancy the fully developed foetus is ready for delivery. the process of childbirth is called parturition which is induced by a complex neuroendocrine mechanism involving cortisol estrogens and oxytocin. mammary glands differentiate during pregnancy and secrete milk after childbirth. the newborn baby is fed milk by the mother lactation during the initial few months of growth. exercises 39 1. fill in the blanks a humans reproduce asexuallysexually b humans are oviparous viviparous ovoviviparous c fertilisation is in humans externalinternal d male and female gametes are diploidhaploid e zygote is diploidhaploid rationalised 202324
#
# Page 15: biology f the process of release of ovum from a mature follicle is called g ovulation is induced by a hormone called h the fusion of male and female gametes is called i fertilisation takes place in j zygote divides to form which is implanted in uterus. k the structure which provides vascular connection between foetus and uterus is called 2. draw a labelled diagram of male reproductive system. 3. draw a labelled diagram of female reproductive system. 4. write two major functions each of testis and ovary. 5. describe the structure of a seminiferous tubule. 6. what is spermatogenesis briefly describe the process of spermatogenesis. 7. name the hormones involved in regulation of spermatogenesis. 8. define spermiogenesis and spermiation. 9. draw a labelled diagram of sperm. 10. what are the major components of seminal plasma 11. what are the major functions of male accessory ducts and glands 12. what is oogenesis give a brief account of oogenesis. 13. draw a labelled diagram of a section through ovary. 14. draw a labelled diagram of a graafian follicle 15. name the functions of the following a corpus luteum b endometrium c acrosome d sperm tail e fimbriae 16. identify truefalse statements. correct each false statement to make it true. a androgens are produced by sertoli cells. truefalse b spermatozoa get nutrition from sertoli cells. truefalse c leydig cells are found in ovary. truefalse d leydig cells synthesise androgens. truefalse e oogenesis takes place in corpus luteum. truefalse f menstrual cycle ceases during pregnancy. truefalse g presence or absence of hymen is not a reliable indicator of virginity or sexual experience. truefalse 17. what is menstrual cycle which hormones regulate menstrual cycle 18. what is parturition which hormones are involved in induction of parturition 19. in our society the women are often blamed for giving birth to daughters. 40 can you explain why this is not correct 20. how many eggs are released by a human ovary in a month how many eggs do you think would have been released if the mother gave birth to identical twins would your answer change if the twins born were fraternal 21. how many eggs do you think were released by the ovary of a female dog which gave birth to 6 puppies rationalised 202324

# %% [markdown]
# # Question Generation

# %%
def generate_questions_for_sentences(sentences, model, tokenizer, page_number, top_k=50, top_p=0.95):
    generated_questions = set()

    num_sentences = len(sentences)

    for i in range(num_sentences - 1):

        selected_sentences = sentences[i:i+10]
        selected_text = ' '.join(selected_sentences)

        input_text_with_prefix = f"Generate a question for the following text (Page {page_number}): {selected_text}"
        inputs = tokenizer(input_text_with_prefix, return_tensors="pt")

        with torch.no_grad():
            outputs = model.generate(
                **inputs,
                max_length=50,
                top_k=top_k,
                top_p=top_p,
                temperature=1.0,
            )

        generated_question = tokenizer.decode(outputs[0], skip_special_tokens=True)
        split_questions = [question.strip() + '?' for question in re.split(r'[.!?]', generated_question)]
        generated_questions.update(split_questions)

    return [{'page': page_number, 'question': question} for question in generated_questions]
def save_questions_to_file(questions, output_file_path='generated_questions.txt'):
    with open(output_file_path, 'w', encoding='utf-8') as file:
        for question_entry in questions:
            question = question_entry['question']
            file.write(question + '\n')


tokenizer = AutoTokenizer.from_pretrained("wiselinjayajos/t5-end2end-questions-generation")
model = AutoModelForSeq2SeqLM.from_pretrained("wiselinjayajos/t5-end2end-questions-generation")



all_generated_questions = []

for i, input_paragraph in enumerate(preprocessed_texts, start=1):
    sentences = re.split(r'[.!?]', input_paragraph)
    generated_questions = generate_questions_for_sentences(sentences, model, tokenizer, page_number=i, top_k=50, top_p=0.95)
    all_generated_questions.extend(generated_questions)


save_questions_to_file(all_generated_questions, output_file_path='generated_questions.txt')


print("Generated Questions:")
for question in all_generated_questions:
    print(question)

print("Generated questions have been saved to 'generated_questions.txt' and printed.")


def save_questions_to_file_csv_with_page(questions, output_file_path='generated_questions_with_page.csv'):
    with open(output_file_path, 'w', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)
        csv_writer.writerow(['Page', 'Generated Questions'])  # Header

        for entry in questions:
            csv_writer.writerow([entry['page'], entry['question']])

save_questions_to_file_csv_with_page(all_generated_questions, output_file_path='generated_questions_with_page.csv')
# Out:
# c:\Users\sriyo\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\generation\configuration_utils.py:367: UserWarning: `do_sample` is set to `False`. However, `top_p` is set to `0.95` -- this flag is only used in sample-based generation modes. You should set `do_sample=True` or unset `top_p`.
#   warnings.warn(
# Generated Questions:
# {'page': 1, 'question': 'What is the reproductive event in humans?'}
# {'page': 1, 'question': 'What is the rationalised 202324?'}
# {'page': 1, 'question': 'Where is the female reproductive system located?'}
# {'page': 1, 'question': '?'}
# {'page': 1, 'question': 'What is the name of the genital tract insemination?'}
# {'page': 1, 'question': 'Where is the male reproductive system located?'}
# {'page': 1, 'question': 'What does sperm formation continue even in old men?'}
# {'page': 1, 'question': 'What is the name?'}
# {'page': 1, 'question': 'What is the male reproductive viviparous?'}
# {'page': 1, 'question': 'What is the external genitalia rationalised 202324?'}
# {'page': 1, 'question': 'What is the female reproductive viviparous?'}
# {'page': 1, 'question': 'What is the male reproductive system located in?'}
# {'page': 1, 'question': 'What is the name of the genital tract insemination and fusion of male and female gametes fertilisation leading to formation of zygote?'}
# {'page': 1, 'question': 'Where is the male reproductive?'}
# {'page': 1, 'question': 'What is the male reproductive system?'}
# {'page': 1, 'question': 'What is the female reproductive system located in?'}
# {'page': 1, 'question': 'What does ovum cease to do in women around fifty years?'}
# {'page': 1, 'question': 'What?'}
# {'page': 1, 'question': 'What is the name of the sperms in males?'}
# {'page': 1, 'question': 'What are the differences between the reproductive events in the male and female?'}
# {'page': 1, 'question': 'What is the name of the sperms in females?'}
# {'page': 1, 'question': 'What is the female reproductive system?'}
# {'page': 1, 'question': 'What is the term for transfer of sperms into the female?'}
# {'page': 1, 'question': 'What is the name of the text that includes a pair of testes along with accessory ducts glands?'}
# {'page': 2, 'question': 'What are the two types?'}
# {'page': 2, 'question': 'How many highly coiled seminiferous tubules are in each lobule?'}
# {'page': 2, 'question': 'What is the vas?'}
# {'page': 2, 'question': 'What are the two types of cells inside each seminiferous tubul?'}
# {'page': 2, 'question': 'What are the regions outside of the seminiferous tubules called?'}
# {'page': 2, 'question': 'What are the two types of cells that line the inside of the seminiferous tubules?'}
# {'page': 2, 'question': 'What do sertoli cells provide?'}
# {'page': 2, 'question': 'What do the seminiferous tubules of the testis open into?'}
# {'page': 2, 'question': '?'}
# {'page': 2, 'question': 'What are the regions outside the seminiferous tubules called?'}
# {'page': 2, 'question': 'What is the pouch that the testes are located outside the abdominal cavity within?'}
# {'page': 2, 'question': 'What are the leydig cells called?'}
# {'page': 2, 'question': 'What do male germ cells undergo?'}
# {'page': 2, 'question': 'What do sertoli cells provide to the germ cells?'}
# {'page': 2, 'question': 'What is the vasa efferentia located along the posterior surface 27 of each testis?'}
# {'page': 2, 'question': 'What is the urethra?'}
# {'page': 2, 'question': 'What is the external opening of the urethra?'}
# {'page': 2, 'question': 'What is the urethra called?'}
# {'page': 2, 'question': 'What is the length of the testis in adults?'}
# {'page': 2, 'question': 'What do the sertoli cells provide?'}
# {'page': 2, 'question': 'What are the two types of cells that line each seminiferous tubule?'}
# {'page': 2, 'question': 'What are?'}
# {'page': 2, 'question': 'What do leydig cells secrete?'}
# {'page': 2, 'question': 'What do the seminiferous tubules?'}
# {'page': 2, 'question': 'What are the regions outside the se?'}
# {'page': 2, 'question': 'What are the male sex accessory duct?'}
# {'page': 2, 'question': 'What?'}
# {'page': 2, 'question': 'What do the seminiferous tubules of the testis open into through rete testis?'}
# {'page': 2, 'question': 'What is the epididymis located along the posterior surface 27 of each testis?'}
# {'page': 2, 'question': 'What do seminiferous tubules of?'}
# {'page': 2, 'question': 'What are interstitial spaces called?'}
# {'page': 2, 'question': 'What is the normal internal body temperature necessary for spermatogenesis in adults?'}
# {'page': 2, 'question': 'What is?'}
# {'page': 2, 'question': 'What is the normal internal body temperature needed for spermatogenesis in adults?'}
# {'page': 2, 'question': 'What are the male sex accessory ducts called?'}
# {'page': 2, 'question': 'What is the pouch called that helps in maintaining the low temperature of the testes?'}
# {'page': 2, 'question': 'How many compartments are in each testis?'}
# {'page': 2, 'question': 'How many compartments are in the testis?'}
# {'page': 2, 'question': 'How many compartments are in?'}
# {'page': 2, 'question': 'What is the length of the testis?'}
# {'page': 2, 'question': 'What do leydig cells synthesise and secrete?'}
# {'page': 2, 'question': 'What do the seminiferous tubules of the testis?'}
# {'page': 2, 'question': 'What is the male reproductive system part of testis open to show inner details androgens other immunologically competent cells are also present in the male sex accessory ducts include rete testis vasa effer?'}
# {'page': 2, 'question': 'What does the urethra originate from?'}
# {'page': 2, 'question': 'What is the external opening called?'}
# {'page': 2, 'question': 'What is the epididymis called?'}
# {'page': 2, 'question': 'What is the male sex accessory duct?'}
# {'page': 2, 'question': 'What helps in maintaining the low temperature of the testes?'}
# {'page': 2, 'question': 'How many highly coiled seminifer?'}
# {'page': 2, 'question': 'What is the ejaculatory duct?'}
# {'page': 2, 'question': 'What are the male sex accessory ducts?'}
# {'page': 2, 'question': 'What is the reproductive system of males?'}
# {'page': 2, 'question': 'What are the two types of cells that line the inside of a seminifer?'}
# {'page': 2, 'question': 'How many highly coiled seminiferous tubules are in the male pelvis?'}
# {'page': 2, 'question': 'What do leydig cells synthesise and secret?'}
# {'page': 2, 'question': 'What are the compartments inside the testis called?'}
# {'page': 2, 'question': 'What do these ducts store and transport?'}
# {'page': 2, 'question': 'What are the two types of cells that line the inside of a seminiferous tubule?'}
# {'page': 2, 'question': 'What is the width of the testis in adults?'}
# {'page': 3, 'question': 'What glands are included in the male accessory glands?'}
# {'page': 3, 'question': 'How many ovaries are located on each side of the lower abdomen?'}
# {'page': 3, 'question': 'What is the secretions of the bulboureth?'}
# {'page': 3, 'question': 'What glands are secreted by the female reproductive system?'}
# {'page': 3, 'question': 'What is the primary female sex organs that produce the female 28 gamete ovum and several steroid hormones ovarian hormones?'}
# {'page': 3, 'question': '?'}
# {'page': 3, 'question': 'What is the seminal plasma rich in?'}
# {'page': 3, 'question': 'What are the primary female sex organs that produce the female?'}
# {'page': 3, 'question': 'What is the length of each?'}
# {'page': 3, 'question': 'What is the secretions of bulbourethral glands also help in?'}
# {'page': 3, 'question': 'What is the male accessory glands called?'}
# {'page': 3, 'question': 'How long is each ovary?'}
# {'page': 3, 'question': 'What is the male external genitalia called?'}
# {'page': 3, 'question': 'What glands are paired seminal vesicles a prostate and paired bulbourethral glands?'}
# {'page': 3, 'question': 'What is the secretions of the glands that are paired seminal ves?'}
# {'page': 3, 'question': 'What is the length of?'}
# {'page': 3, 'question': 'What is the enlarged end of penis called?'}
# {'page': 3, 'question': 'What glands help in the lubric?'}
# {'page': 3, 'question': 'What is the secretions of?'}
# {'page': 3, 'question': 'What is the inner medulla?'}
# {'page': 3, 'question': 'What is the male accessory glands?'}
# {'page': 3, 'question': 'What is the ovarian stroma divided into?'}
# {'page': 3, 'question': 'What?'}
# {'page': 3, 'question': 'What are the ovaries located on each side of?'}
# {'page': 3, 'question': 'What is the fold of skin on the enlarged end of penis called?'}
# {'page': 3, 'question': 'What is the fold of skin that covers the enlarged end of penis called?'}
# {'page': 3, 'question': 'What is?'}
# {'page': 3, 'question': 'What are the male accessory glands?'}
# {'page': 3, 'question': 'What are the primary female sex organs?'}
# {'page': 3, 'question': 'What is the stroma divided into?'}
# {'page': 3, 'question': 'What is the ovary covered by?'}
# {'page': 3, 'question': 'What is the female reproductive system composed of?'}
# {'page': 3, 'question': 'What is the length of each ovary?'}
# {'page': 3, 'question': 'What is the primary female sex organs that produce the female?'}
# {'page': 3, 'question': 'What is the inner medulla rationalised 202324?'}
# {'page': 3, 'question': 'What is the male external genitalia?'}
# {'page': 4, 'question': 'What is the length of each fallopian tube?'}
# {'page': 4, 'question': 'What is the female accessory ducts?'}
# {'page': 4, 'question': 'What is the part closer to the ovary called?'}
# {'page': 4, 'question': 'What is the infundibulum that leads to a wider view of the female reproductive system?'}
# {'page': 4, 'question': '?'}
# {'page': 4, 'question': 'What is the?'}
# {'page': 4, 'question': 'What do fimbriae do?'}
# {'page': 4, 'question': 'What year was the female reproductive system rationalised?'}
# {'page': 4, 'question': 'What are fimbriae?'}
# {'page': 4, 'question': 'What is the infundibulum called?'}
# {'page': 4, 'question': 'What is the name of the projections on the edges of the infundibulum called?'}
# {'page': 4, 'question': 'What is the name of the part closer to the ovary called?'}
# {'page': 4, 'question': 'What?'}
# {'page': 5, 'question': 'What is the outer thin membranous perimetrium middle thick layer of smooth muscle myometrium and?'}
# {'page': 5, 'question': 'What is the name of the tiny fingerlike structure that lies at the upper junction of the two labia minora above the urethral opening?'}
# {'page': 5, 'question': 'What is the external thin membranous perimetrium?'}
# {'page': 5, 'question': '?'}
# {'page': 5, 'question': 'What is the membrane that covers the opening of the vagina called?'}
# {'page': 5, 'question': 'What is the inner glandular?'}
# {'page': 5, 'question': 'What is the clitoris?'}
# {'page': 5, 'question': 'What is the hymen often to?'}
# {'page': 5, 'question': 'What is the opening of the vagina often covered partially?'}
# {'page': 5, 'question': 'What is the hymen called?'}
# {'page': 5, 'question': 'What is the hymen often torn during?'}
# {'page': 5, 'question': 'What is the outer thin membranous perimetrium middle thick layer of smooth muscle myometrium and inner glandular layer called called?'}
# {'page': 5, 'question': 'What is the hymen?'}
# {'page': 5, 'question': 'What is the cavity of the cervix?'}
# {'page': 5, 'question': 'What is the inner glandular layer called?'}
# {'page': 5, 'question': 'What is the cavity of the cervix called?'}
# {'page': 5, 'question': 'What is often torn during the first coitus intercourse?'}
# {'page': 5, 'question': 'What is the hymen often broken by?'}
# {'page': 5, 'question': 'What is the outer thin membranous peri?'}
# {'page': 5, 'question': 'What is the inner glandular layer called called that lines the uterine cavity?'}
# {'page': 5, 'question': 'What?'}
# {'page': 5, 'question': 'What is the cushion of fatty tissue covered by?'}
# {'page': 5, 'question': 'What is the name of the membrane that covers the opening of the vagina?'}
# {'page': 5, 'question': 'What is the most reliable indicator of virginity or sexual experience?'}
# {'page': 5, 'question': 'What can break the hymen?'}
# {'page': 5, 'question': 'What is the outer thin membranous perimetrium middle thick layer of smooth muscle myometrium?'}
# {'page': 5, 'question': 'What is not a reliable indicator of virginity or sexual experience?'}
# {'page': 5, 'question': 'What is the question for the following text?'}
# {'page': 5, 'question': 'What is the?'}
# {'page': 5, 'question': 'What is the uterus also called?'}
# {'page': 5, 'question': 'What is the birth canal called?'}
# {'page': 5, 'question': 'What is the last part of the oviduct isthmus called?'}
# {'page': 5, 'question': 'What are fleshy folds of tissue that extend down from the mons pubis and surround the vaginal opening?'}
# {'page': 5, 'question': 'What are labia majora?'}
# {'page': 5, 'question': 'What is the outer layer of the uterus called?'}
# {'page': 5, 'question': 'What is the female external genitalia called?'}
# {'page': 5, 'question': 'What is the shape of the uterus like?'}
# {'page': 5, 'question': 'What can also be broken by a sudden fall or jolt?'}
# {'page': 5, 'question': 'What is the clitoris called?'}
# {'page': 5, 'question': 'What are labia minora?'}
# {'page': 6, 'question': 'What do the tubules of?'}
# {'page': 6, 'question': 'What do the alveoli open into?'}
# {'page': 6, 'question': 'What gland is gnrh acting at?'}
# {'page': 6, 'question': 'How many mammary lobes are there?'}
# {'page': 6, 'question': 'What is the name of the hormone that increases the seminiferous tubule?'}
# {'page': 6, 'question': 'What is the number of chromosomes in spermatids?'}
# {'page': 6, 'question': 'What are mamm?'}
# {'page': 6, 'question': 'What do the tubules of each lobe join to form?'}
# {'page': 6, 'question': 'What is connected to lactiferous duct through which milk is sucked out?'}
# {'page': 6, 'question': 'When does spermiation begin?'}
# {'page': 6, 'question': 'How many chromosomes does each spermatogonium contain?'}
# {'page': 6, 'question': '?'}
# {'page': 6, 'question': 'What is the name of the process that produces sperms?'}
# {'page': 6, 'question': 'What is the process called after spermiogenesis?'}
# {'page': 6, 'question': 'What are mammary glands?'}
# {'page': 6, 'question': 'What is the name?'}
# {'page': 6, 'question': 'What is the process called that produces sperms?'}
# {'page': 6, 'question': 'What is the process called that?'}
# {'page': 6, 'question': 'What is the process called that produces sperm?'}
# {'page': 6, 'question': 'What hormone acts at the leydig cells?'}
# {'page': 6, 'question': 'What hormone acts at the anterior pituitary gland?'}
# {'page': 6, 'question': 'What is the process called that produces spermatozoa sperms?'}
# {'page': 6, 'question': 'What do the cells of alveoli open into?'}
# {'page': 6, 'question': 'What is the process called that releases sperm heads from the seminiferous tubules?'}
# {'page': 6, 'question': 'What hormone is produced by the anterior pituitary gland?'}
# {'page': 6, 'question': 'What are the mammary glands?'}
# {'page': 6, 'question': 'What is the process called that produces sperms in testis?'}
# {'page': 6, 'question': 'What is characteristic of all female mammals?'}
# {'page': 6, 'question': 'What does fsh act on?'}
# {'page': 6, 'question': 'What hormone acts on the sertoli cells?'}
# {'page': 6, 'question': 'What is the name of the hormone that increases the se?'}
# {'page': 6, 'question': 'What?'}
# {'page': 6, 'question': 'What do the cells of alveoli secrete?'}
# {'page': 6, 'question': 'How many chromosomes are in each spermatogonium?'}
# {'page': 6, 'question': 'What is the glandular tissue of each breast divided into?'}
# {'page': 6, 'question': 'What is the?'}
# {'page': 6, 'question': 'What is the process called that transforms spermatids?'}
# {'page': 6, 'question': 'What hormone is produced by the anterior?'}
# {'page': 6, 'question': 'What is the process called that produces spermatozoa?'}
# {'page': 6, 'question': 'What is the process of sper?'}
# {'page': 6, 'question': 'What cells does lh act at?'}
# {'page': 6, 'question': 'What is the process called that transforms spermatids into spermatozoa sperms?'}
# {'page': 6, 'question': 'What is the process of spermatogenesis?'}
# {'page': 6, 'question': 'What is the process of spermatogenesis that is stimulated by androgens?'}
# {'page': 6, 'question': 'What hormone is released at the anterior pituitary gland?'}
# {'page': 6, 'question': 'What is the name of the spermatogonium present on the inside wall of seminiferous tubules?'}
# {'page': 7, 'question': 'What is the rationalised 202324?'}
# {'page': 7, 'question': 'What is the first meiotic division of the primary oocyte?'}
# {'page': 7, 'question': 'What is the second meiotic division?'}
# {'page': 7, 'question': 'What is the process of formation of a mature female gamete called?'}
# {'page': 7, 'question': 'What is the sperm head composed of?'}
# {'page': 7, 'question': 'What are the primary follicles called?'}
# {'page': 7, 'question': '?'}
# {'page': 7, 'question': 'What is the inner theca interna?'}
# {'page': 7, 'question': 'What is the first polar body?'}
# {'page': 7, 'question': 'What is the structure of a sperm?'}
# {'page': 7, 'question': 'How many sper?'}
# {'page': 7, 'question': 'What is the formation of a large?'}
# {'page': 7, 'question': 'How many sperm?'}
# {'page': 7, 'question': 'What are the?'}
# {'page': 7, 'question': 'What is the structure of a sperm composed of?'}
# {'page': 7, 'question': 'What is the body of sperm covered by?'}
# {'page': 7, 'question': 'What are the testicular hormones androgens used for?'}
# {'page': 7, 'question': 'What is the secondary follicle called?'}
# {'page': 7, 'question': 'What is the outer theca externa?'}
# {'page': 7, 'question': 'What is the tertiary?'}
# {'page': 7, 'question': 'What are the functions of male sex accessory ducts and glands maintained by?'}
# {'page': 7, 'question': 'What is the sperm head covered by?'}
# {'page': 7, 'question': 'What are the seminal plasma along with the sperms essential for?'}
# {'page': 7, 'question': 'How many sperms does the human male ejaculate during a coitus?'}
# {'page': 7, 'question': 'What is the primary oocyte called?'}
# {'page': 7, 'question': 'What is the tertiary follicle arranged into?'}
# {'page': 7, 'question': 'What is the primary oocyte within the tertiary follicle?'}
# {'page': 7, 'question': 'What are the secretions of epididymis vas deferens essential for?'}
# {'page': 7, 'question': 'What are the primary follicles called at puberty?'}
# {'page': 7, 'question': 'What percentage of sperms must show?'}
# {'page': 7, 'question': 'What are the functions of male sex accessory?'}
# {'page': 7, 'question': 'What is the tertiary follicle characterized by?'}
# {'page': 7, 'question': 'What is the body of sperm?'}
# {'page': 7, 'question': 'What are the primary oocytes called?'}
# {'page': 7, 'question': 'What is the?'}
# {'page': 7, 'question': 'What is the process of formation of a mature female gamete markedly different from?'}
# {'page': 7, 'question': 'What is the result of the unequal division?'}
# {'page': 7, 'question': 'What is the primary follicle called?'}
# {'page': 7, 'question': 'How many sperms must have normal shape and size for normal fertility?'}
# {'page': 7, 'question': 'How many sperms does a?'}
# {'page': 7, 'question': 'How many sperms does a human male ejaculate during a coitus?'}
# {'page': 7, 'question': 'When is oogenesis initiated?'}
# {'page': 7, 'question': 'What is the tertiary follicle characterised by?'}
# {'page': 7, 'question': 'What is the first stage of oogenesis?'}
# {'page': 7, 'question': 'What is the acrosome filled with?'}
# {'page': 7, 'question': 'What is the structure of a sper?'}
# {'page': 7, 'question': 'How many?'}
# {'page': 7, 'question': 'What is the process of formation of?'}
# {'page': 8, 'question': 'What is the process called that releases the secondary oocyte ovum from the ovary?'}
# {'page': 8, 'question': 'What is the name of the membrane that surrounds the secondary oocyte called?'}
# {'page': 8, 'question': '?'}
# {'page': 8, 'question': 'What is the first menstruation called in human females?'}
# {'page': 8, 'question': 'How many days is the average interval of menstruation?'}
# {'page': 8, 'question': 'What is the name of the process that?'}
# {'page': 8, 'question': 'What is the reproductive cycle in the female primates?'}
# {'page': 8, 'question': 'What is the diagrammatic representation of?'}
# {'page': 8, 'question': 'What is the reproductive cycle in humans called?'}
# {'page': 8, 'question': 'What is the reproductive cycle in female primates called?'}
# {'page': 8, 'question': 'How many days is the average interval of menstru?'}
# {'page': 8, 'question': 'What?'}
# {'page': 8, 'question': 'When is ovum released ovulation?'}
# {'page': 8, 'question': 'What is the reproductive cycle in primates?'}
# {'page': 8, 'question': 'What is the first menstruation called in humans?'}
# {'page': 8, 'question': 'When is?'}
# {'page': 8, 'question': 'What is the average interval of menstruation in human females?'}
# {'page': 8, 'question': 'What is the first menstruation called in monkeys apes and human beings?'}
# {'page': 8, 'question': 'What is the membrane that surrounds the secondary oocyte called?'}
# {'page': 8, 'question': 'What is the term for the membrane that surrounds the secondary oocyte called?'}
# {'page': 8, 'question': 'What is the process called that releases the secondary o?'}
# {'page': 8, 'question': 'What is the reproductive cycle in the female primates e g monkeys apes and humans called?'}
# {'page': 8, 'question': 'What is the reproductive cycle in the female primates called?'}
# {'page': 8, 'question': 'What is the reproductive cycle in human females called?'}
# {'page': 8, 'question': 'What is the process called that releases the secondary oocyte ovum from the?'}
# {'page': 8, 'question': 'What is the name of the membrane that the secondary oocyte forms around it?'}
# {'page': 8, 'question': 'What is the reproductive cycle in humans?'}
# {'page': 8, 'question': 'What is the term for the mature follicle?'}
# {'page': 8, 'question': 'When does the first menstruation begin in human females?'}
# {'page': 8, 'question': 'What is the cycle of events starting from one menstruation till the next one called?'}
# {'page': 9, 'question': 'What phase is followed by the menstrual phase?'}
# {'page': 9, 'question': '?'}
# {'page': 9, 'question': 'What is the main event of the menstrual cycle?'}
# {'page': 9, 'question': 'What is the breakdown of the endometrial lining of the uterus and its blood vessels that forms liquid that comes out through vagina?'}
# {'page': 9, 'question': 'What is the secretion of rationalised 202324?'}
# {'page': 9, 'question': 'What is the menstrual?'}
# {'page': 9, 'question': 'What is the cause of the breakdown of the endometrial lining of the uterus and its blood vessels?'}
# {'page': 9, 'question': 'What is the first phase of the menstrual cycle?'}
# {'page': 9, 'question': 'What is the only time menstruation occurs?'}
# {'page': 9, 'question': 'What phase is followed by the follicular phase?'}
# {'page': 9, 'question': 'What is the duration of the menstrual cycle?'}
# {'page': 9, 'question': 'What is the duration of the cycle?'}
# {'page': 9, 'question': 'What is the menstrual phase followed by?'}
# {'page': 9, 'question': 'What does the endometrium of uterus regenerate through?'}
# {'page': 9, 'question': 'What is the result of the breakdown of the endometrial lining of the uterus and its blood vessels?'}
# {'page': 9, 'question': 'What hormones are induced by changes in the ovary and?'}
# {'page': 9, 'question': 'What is the menstrual phase?'}
# {'page': 9, 'question': 'What is the first phase of the cycle?'}
# {'page': 9, 'question': 'What is the result?'}
# {'page': 9, 'question': 'What is the endometrium of uterus regenerating through?'}
# {'page': 9, 'question': 'What hormones are induced by changes in the ova?'}
# {'page': 9, 'question': 'What hormones are involved in the ovulation and uterus?'}
# {'page': 9, 'question': 'What is the menstrual flow?'}
# {'page': 9, 'question': 'What is the follicular phase?'}
# {'page': 9, 'question': 'What do the primary follicles in the ovary grow to become?'}
# {'page': 9, 'question': 'What is the menstrual flow caused by?'}
# {'page': 10, 'question': 'What is the zona pellucida?'}
# {'page': 10, 'question': 'What is the luteal phase?'}
# {'page': 10, 'question': 'What is the process of fusion of a sperm with an ovum called?'}
# {'page': 10, 'question': 'What is the corpus homemade pads called?'}
# {'page': 10, 'question': 'What does fertilisation do to the?'}
# {'page': 10, 'question': 'What is the term used for the menstrual cycles that ceases around 50 years of age?'}
# {'page': 10, 'question': '?'}
# {'page': 10, 'question': 'What is the term for the absence of sanitary napkins of fertilisation?'}
# {'page': 10, 'question': 'What causes disintegration properly wrapping it with a used paper do of the endometrium leading to menstruation marking a new cycle in not?'}
# {'page': 10, 'question': 'What is the term for the menopause?'}
# {'page': 10, 'question': 'What is the process of fusion of a?'}
# {'page': 10, 'question': 'What is the corpus luteum secreted?'}
# {'page': 10, 'question': 'What is the corpus?'}
# {'page': 10, 'question': 'What is the corpus luteum secreted large amounts of?'}
# {'page': 10, 'question': 'What hormone is secrete?'}
# {'page': 10, 'question': 'What is the acrosome secretions that help the sperm enter into the cytoplasm of the ovum through the zona pellucida and the plasma figure 2 10 ovum surrounded by few?'}
# {'page': 10, 'question': 'What secretions help the sperm enter into the cytoplasm of the ovum?'}
# {'page': 10, 'question': 'What is the plasma figure 2 10 ovum surrounded by few?'}
# {'page': 10, 'question': 'What is the peak level of lh and fsh?'}
# {'page': 10, 'question': 'What is the luteal phase followed by?'}
# {'page': 10, 'question': 'What is the term for the meno?'}
# {'page': 10, 'question': 'What hormones are secreted by the growing follicles during the luteal phase?'}
# {'page': 10, 'question': 'What is the term for the cycle that ends around 50 years of age?'}
# {'page': 10, 'question': 'What is the term for the menstrual cycle that ends around 50 years of age?'}
# {'page': 10, 'question': 'What is released by the penis into the vagina?'}
# {'page': 10, 'question': 'What is the term?'}
# {'page': 10, 'question': 'What is the process of fusion of a sper?'}
# {'page': 10, 'question': 'What is the corpus luteum essential for maintenance of?'}
# {'page': 10, 'question': 'What is the release of ovum ovulation?'}
# {'page': 10, 'question': 'What is the maximum level of lh during the midcycle called?'}
# {'page': 10, 'question': 'What?'}
# {'page': 10, 'question': 'What does the acrosome help the sperm enter into the cytoplasm of the ovum through the zona pellucida and the plasma?'}
# {'page': 10, 'question': 'What is essential for maintenance of the endometrium napkins or homemade?'}
# {'page': 10, 'question': 'What is the ovum surrounded by few?'}
# {'page': 10, 'question': 'What does fertilisation do to the ovum?'}
# {'page': 10, 'question': 'What causes disintegration properly wrapping it with a used paper do of the endometrium leading to menstruation?'}
# {'page': 10, 'question': 'What does the sperm induce that blocks the entry of additional sperms?'}
# {'page': 10, 'question': 'What layer of the ovum is in contact with during fertilisation?'}
# {'page': 10, 'question': 'What hormone is secreted by the corpus luteum during the luteal phase?'}
# {'page': 10, 'question': 'What is released by the pen?'}
# {'page': 10, 'question': 'What is the secreted change sanitary progesterone essential for maintenance of?'}
# {'page': 10, 'question': 'What is the maximum level during the midcycle called?'}
# {'page': 10, 'question': 'What is necessary for implantation of fertilised pads after every 45 hrs as per the requirement ovum and other events of pregnancy during pregnancy?'}
# {'page': 10, 'question': 'What is an indicator of normal drainpipe of toilets or reproductive phase?'}
# {'page': 10, 'question': 'What is the corpus luteum secreted for?'}
# {'page': 10, 'question': 'What is necessary for implantation of fertilised pads after every 45 hrs as?'}
# {'page': 10, 'question': 'What is the process of?'}
# {'page': 10, 'question': 'What is fertilisation?'}
# {'page': 10, 'question': 'How many sperms can fertilise an o?'}
# {'page': 10, 'question': 'What is the term used for the menopause?'}
# {'page': 10, 'question': 'What is the ampullary region where fertilisation takes place?'}
# {'page': 10, 'question': 'What is the luteal phase of the graafian follicle?'}
# {'page': 11, 'question': 'What is the second meiotic division?'}
# {'page': 11, 'question': 'What would a zygote carrying xx develop into?'}
# {'page': 11, 'question': 'What is the sex of the baby determined?'}
# {'page': 11, 'question': '?'}
# {'page': 11, 'question': 'What would a zygote carrying xy form a male baby?'}
# {'page': 11, 'question': 'What would the zygote carry xy form?'}
# {'page': 11, 'question': 'What would the zygote carry xx develop into?'}
# {'page': 11, 'question': 'What?'}
# {'page': 11, 'question': 'What is the mitotic division started as the zygote moves through the isthmus of the ovi?'}
# {'page': 11, 'question': 'What is?'}
# {'page': 11, 'question': 'What is the number of embryos in the embryo?'}
# {'page': 11, 'question': 'What is the chromosome pattern in the male?'}
# {'page': 11, 'question': 'What is the chromosome pattern in the human female?'}
# {'page': 11, 'question': 'What would the zygote carry after fusion of the male and female gametes?'}
# {'page': 11, 'question': 'What percentage of sperms carry the x chromosome?'}
# {'page': 11, 'question': 'What is the sex of the baby determined by?'}
# {'page': 11, 'question': 'What cells are called blastomeres the embryo with 8 to 16 36 figure 2 11 transport of ovum fertilisation and passage of growing embryo through fallopian tube rationalised 202324?'}
# {'page': 11, 'question': 'What percentage of sper?'}
# {'page': 11, 'question': 'What percentage of sperms carry the y chromosome?'}
# {'page': 12, 'question': 'What is the placenta?'}
# {'page': 12, 'question': 'What hormone is secreted by the ovary?'}
# {'page': 12, 'question': '?'}
# {'page': 12, 'question': 'What is the human reproduction blastomeres called?'}
# {'page': 12, 'question': 'What is the name of the trophoblast that is surrounded by the uterine tissue and maternal blood?'}
# {'page': 12, 'question': 'What is the name of the text that differentiates the embryo after implantation?'}
# {'page': 12, 'question': 'What is the term for the trophoblast that is surrounded?'}
# {'page': 12, 'question': 'What is the process of implantation called?'}
# {'page': 12, 'question': 'What is the placenta connected to?'}
# {'page': 12, 'question': 'What hormone is secreted by the ovary during pregnancy?'}
# {'page': 12, 'question': 'What hormone is secreted by the ovary in the later phase of pregnancy?'}
# {'page': 12, 'question': 'What is the name of the hormone secreted by?'}
# {'page': 12, 'question': 'What is the name of the text that is based on the human foetus within the uterus rationalised 202324?'}
# {'page': 12, 'question': 'What is the main reason for increased production of these hormones?'}
# {'page': 12, 'question': 'What is the term for the trophoblast that is surrounded by the uterine tissue and maternal blood?'}
# {'page': 12, 'question': 'What is the outer layer of the blast?'}
# {'page': 12, 'question': 'What is the inner cell mass called?'}
# {'page': 12, 'question': 'What is the outer layer of the blastomeres called?'}
# {'page': 12, 'question': 'What?'}
# {'page': 12, 'question': 'What is the 11 step h that leads to?'}
# {'page': 12, 'question': 'What hormones are produced in women only during pregnancy?'}
# {'page': 12, 'question': 'What is the?'}
# {'page': 12, 'question': 'What is the name of the trophoblast that is surrounded by uterine tissue and maternal blood?'}
# {'page': 12, 'question': 'What is the name of the hormone secreted by the ovary during pregnancy?'}
# {'page': 12, 'question': 'What is the name of the text that is based on the human foetus within?'}
# {'page': 12, 'question': 'What is the outer layer of the blastomeres in the blastocyst called?'}
# {'page': 12, 'question': 'What is the outer layer of human reproduction blastomeres called?'}
# {'page': 12, 'question': 'What is the process that leads to pregnancy?'}
# {'page': 12, 'question': 'What is the main reason for increased?'}
# {'page': 12, 'question': 'What is the placen?'}
# {'page': 12, 'question': 'What is the inner cell mass attached to the outer layer of the blastomeres?'}
# {'page': 12, 'question': 'What is the placenta endocrine tissue?'}
# {'page': 12, 'question': 'What is the 11 step h that leads to pregnancy?'}
# {'page': 13, 'question': 'What triggers release of oxytoc?'}
# {'page': 13, 'question': 'How long does human pregnancy last in dogs elephants cats find out in humans after one month of pregnancy?'}
# {'page': 13, 'question': 'What do the three layers give rise to in adults?'}
# {'page': 13, 'question': 'What is the first sign of growing foetus in human beings?'}
# {'page': 13, 'question': 'What causes stronger uterine contractions?'}
# {'page': 13, 'question': 'What is the first time a baby is breast?'}
# {'page': 13, 'question': 'What is the average duration of human pregnancy called?'}
# {'page': 13, 'question': '?'}
# {'page': 13, 'question': 'What is the process of delivery of the foetus called?'}
# {'page': 13, 'question': 'What does oxytocin do to the uterine muscle?'}
# {'page': 13, 'question': 'What is the main feature of embryonic development at various months of pregnancy?'}
# {'page': 13, 'question': 'What is the process called during pregnancy called?'}
# {'page': 13, 'question': 'How long does human pregnancy last?'}
# {'page': 13, 'question': 'What is the inner cell mass called?'}
# {'page': 13, 'question': 'What is the inner cell mass of the embryo called?'}
# {'page': 13, 'question': 'What are the three layers that give rise?'}
# {'page': 13, 'question': 'What is the first sign of growing foetus?'}
# {'page': 13, 'question': 'What is parturition induced by?'}
# {'page': 13, 'question': 'How long does a human pregnancy last?'}
# {'page': 13, 'question': 'What?'}
# {'page': 13, 'question': 'What is the outer layer called?'}
# {'page': 13, 'question': 'What is the process called during lactation?'}
# {'page': 13, 'question': 'What is the process called that helps?'}
# {'page': 13, 'question': 'What is the process called that helps the mother in feeding the new born?'}
# {'page': 13, 'question': 'How long does the human pregnancy last?'}
# {'page': 13, 'question': 'What is the average duration of human pregnancy?'}
# {'page': 13, 'question': 'What triggers release of oxytocin from the maternal pituit?'}
# {'page': 13, 'question': 'What are the cells called in the inner cell mass?'}
# {'page': 13, 'question': 'What is the first sign of growing foetus noticed by listening to the heart sound carefully through the stethoscope?'}
# {'page': 13, 'question': 'How long does human pregnancy last in dogs elephants cats find out in humans?'}
# {'page': 13, 'question': 'What is the gestation period?'}
# {'page': 13, 'question': 'What is parturition?'}
# {'page': 13, 'question': 'What is the first time a baby is breastfed?'}
# {'page': 13, 'question': 'By the end of the second month of pregnancy the foetus develops limbs and digits by the end of 12 weeks first trimester most of the major organ systems are formed by the end of 12 weeks first trim?'}
# {'page': 13, 'question': 'What triggers release?'}
# {'page': 13, 'question': 'What is the process called during pregnancy that helps the mother in feeding the new born?'}
# {'page': 13, 'question': 'What is the inner layer called?'}
# {'page': 13, 'question': 'What triggers release of oxytocin from the maternal?'}
# {'page': 13, 'question': 'What is the first sign of growing foetus noticed by listening?'}
# {'page': 13, 'question': 'How long does pregnancy last in dogs elephants cats?'}
# {'page': 13, 'question': 'How long does the human pregnancy last in dogs elephants cats?'}
# {'page': 13, 'question': 'What is the milk produced during the initial few days of lactation called?'}
# {'page': 13, 'question': 'What triggers release of oxytocin from the maternal pituitary?'}
# {'page': 14, 'question': '" What is the name of the text that is based on the question "What is?'}
# {'page': 14, 'question': 'What are the ovarian hormones embedded in?'}
# {'page': 14, 'question': 'What is the name of the exercise that answers the question?'}
# {'page': 14, 'question': '?'}
# {'page': 14, 'question': 'What is the female gamete ovum produced by?'}
# {'page': 14, 'question': 'What is one of the female external genitalia?'}
# {'page': 14, 'question': 'What is the process of childbirth called?'}
# {'page': 14, 'question': 'How many highly coiled seminiferous tubules are in each testis?'}
# {'page': 14, 'question': 'What do sertoli cells provide to the germ cells?'}
# {'page': 14, 'question': 'What are the?'}
# {'page': 14, 'question': 'What is the name of the exercise that answers the?'}
# {'page': 14, 'question': 'How many compartments does each testis have?'}
# {'page': 14, 'question': 'What is the reproductive cycle of female primates called?'}
# {'page': 14, 'question': 'What is the male external genitalia called?'}
# {'page': 14, 'question': 'What are the oviducts?'}
# {'page': 14, 'question': 'What is the process of formation of mature female gametes called?'}
# {'page': 14, 'question': 'What is the process of formation of mature female gametes?'}
# {'page': 14, 'question': 'What are the oviducts uterus and vagina?'}
# {'page': 14, 'question': 'What are the three layers of the?'}
# {'page': 14, 'question': 'What is the newborn baby fed by the mother?'}
# {'page': 14, 'question': 'What are the ovaries producing?'}
# {'page': 14, 'question': 'What is the female external genitalia?'}
# {'page': 14, 'question': 'What is the process of childbirth?'}
# {'page': 14, 'question': 'What is parturition induced by?'}
# {'page': 14, 'question': 'What is fertil?'}
# {'page': 14, 'question': 'What do leydig cells outside the seminiferous tubules synthesise and secrete?'}
# {'page': 14, 'question': 'What are the three?'}
# {'page': 14, 'question': 'What?'}
# {'page': 14, 'question': 'What is one of the female secondary sexual characteristics?'}
# {'page': 14, 'question': 'What is fertilisation in humans externalinternal?'}
# {'page': 14, 'question': 'What is the first stage of menstrual cycle?'}
# {'page': 14, 'question': 'What hormones are involved in ovulation?'}
# {'page': 14, 'question': 'What is?'}
# {'page': 14, 'question': "What is the uterus's third layer?"}
# {'page': 14, 'question': 'How many compartments are in each testis?'}
# {'page': 14, 'question': 'What is the male reproductive system composed of?'}
# {'page': 14, 'question': 'What do sertoli cells provide to the dividing germ cells?'}
# {'page': 14, 'question': 'What glands differentiate during pregnancy and secrete milk after childbirth?'}
# {'page': 14, 'question': 'What do spermatogonia undergo?'}
# {'page': 14, 'question': 'What is fed by the mother after childbirth?'}
# {'page': 14, 'question': 'What is parturition?'}
# {'page': 14, 'question': 'What do mammary glands differentiate during pregnancy and secrete after childbirth?'}
# {'page': 14, 'question': 'What is the normal human sperm composed of?'}
# {'page': 14, 'question': 'What are the ovarian follicles embedded in?'}
# {'page': 14, 'question': 'What is the zygote is rationalised 20?'}
# {'page': 14, 'question': 'What hormones are involved in the cyclical changes in the ovary and uterus during menstrual cycle?'}
# {'page': 14, 'question': 'What are the testicular lobules called?'}
# {'page': 14, 'question': 'What are testicular hormones called?'}
# {'page': 14, 'question': 'What is the female reproductive system composed of?'}
# {'page': 14, 'question': 'What hormones are involved in the cyclical changes in?'}
# {'page': 14, 'question': 'What determines the sex of the embryo?'}
# {'page': 14, 'question': 'What is the name of the text that is based on the question "What is the name of the text that is based on the question "?'}
# {'page': 14, 'question': 'What is the name of the process of childbirth?'}
# {'page': 15, 'question': 'What is the fusion of male and female gametes called?'}
# {'page': 15, 'question': 'What are spermatozoa get nutrition from?'}
# {'page': 15, 'question': 'What are the hormones involved in regulation of spermatogenesis?'}
# {'page': 15, 'question': 'What are the major functions of male accessory ducts and glands?'}
# {'page': 15, 'question': 'What type of cell is?'}
# {'page': 15, 'question': 'What type of cell is found in ovary?'}
# {'page': 15, 'question': 'What do truefalse b spermatozoa get nutrition from?'}
# {'page': 15, 'question': 'What is a graafian follicle?'}
# {'page': 15, 'question': 'What is the name of the graafian?'}
# {'page': 15, 'question': 'What are the functions of the following?'}
# {'page': 15, 'question': 'What hormones regulate menstrual cycle?'}
# {'page': 15, 'question': 'How many eggs are released by a human ova?'}
# {'page': 15, 'question': 'How?'}
# {'page': 15, 'question': '?'}
# {'page': 15, 'question': 'How many eggs do you think would have been released if the mother gave birth to identical twins would your answer change if the twins born were?'}
# {'page': 15, 'question': 'What are androgens produced by?'}
# {'page': 15, 'question': 'What is oo?'}
# {'page': 15, 'question': 'What is the name of the graafian follicle?'}
# {'page': 15, 'question': 'What cells produce and?'}
# {'page': 15, 'question': 'Where are truefalse c leydig cells found?'}
# {'page': 15, 'question': 'Name the hormones involved in regulation of spermatogenesis?'}
# {'page': 15, 'question': 'What are the two major functions of testis and ovary?'}
# {'page': 15, 'question': 'What hormone induces ovulation?'}
# {'page': 15, 'question': 'What is the structure which provides vascular connection between foetus and uterus called?'}
# {'page': 15, 'question': 'What type of cells produce androgens?'}
# {'page': 15, 'question': 'How many eggs are released by a human ovary in a month?'}
# {'page': 15, 'question': 'What is the name of the function of the following?'}
# {'page': 15, 'question': 'What is the structure of a seminiferous tubule?'}
# {'page': 15, 'question': 'What type of cells are found in ovary?'}
# {'page': 15, 'question': 'What is not a reliable indicator of virginity or sexual experience truefalse g presence or absence of hymen is not a reliable indicator of virginity or sexual experience truefalse?'}
# {'page': 15, 'question': 'What is spermatogenesis?'}
# {'page': 15, 'question': 'What is spermatogenesis briefly describe the process of spermatogenesis?'}
# {'page': 15, 'question': 'Where does?'}
# {'page': 15, 'question': 'What?'}
# {'page': 15, 'question': 'Where does oogenesis take place?'}
# {'page': 15, 'question': 'How many eggs?'}
# {'page': 15, 'question': 'What is not a reliable indicator of virginity or sexual experience?'}
# {'page': 15, 'question': 'What is often blamed for giving birth to daughters?'}
# {'page': 15, 'question': 'What is the?'}
# {'page': 15, 'question': 'What is spermiation?'}
# {'page': 15, 'question': 'What happens during pregnancy?'}
# {'page': 15, 'question': 'Name the functions?'}
# {'page': 15, 'question': 'What cells are found in ovary?'}
# {'page': 15, 'question': 'How many eggs are released by a human ovary in?'}
# {'page': 15, 'question': 'What cells produce androgens?'}
# {'page': 15, 'question': 'Where do truefalse e oogenesis take place?'}
# {'page': 15, 'question': 'What is parturition?'}
# {'page': 15, 'question': 'What is the structure which provides?'}
# {'page': 15, 'question': 'What is spermatogenesis briefly describe the process?'}
# {'page': 15, 'question': 'What are the major components of seminal plasma?'}
# {'page': 15, 'question': 'How many eggs do you think would have been released if the?'}
# {'page': 15, 'question': 'What is spermiogenesis?'}
# {'page': 15, 'question': 'What is oogenesis?'}
# {'page': 15, 'question': 'Name the functions of the following a corpus luteum b endo?'}
# {'page': 15, 'question': 'What hormones are involved in induction of parturition?'}
# {'page': 15, 'question': 'What is the process of release of ovum from a mature follicle called?'}
# {'page': 15, 'question': 'Where do truefalse d leydig cells synthesise androgens?'}
# {'page': 15, 'question': 'What is not a reliable indicator of virginity or sexual experience truefalse g presence or absence of hymen is not a reliable indicator of virginity or sexual experience truefalse g presence or absence of?'}
# {'page': 15, 'question': 'What is oogenesis give a brief account of oogenesis?'}
# Generated questions have been saved to 'generated_questions.txt' and printed.

# %%
with open("generated_questions_with_page.csv", 'r', encoding='utf-8') as file:
        generated_questions = file.readlines()

# %%
questions_only = [line.split(',')[1].strip() for line in generated_questions[1:]]

# %%
len(questions_only)
# Out:
# 581

# %% [markdown]
# ## To read preprocessed text

# %%
file_path = "preprocessed_paragraphs.txt"
preprocessed_texts= []
with open(file_path, 'r', encoding='utf-8') as file:
    for line in file:
        preprocessed_texts.append(line.strip())

# %% [markdown]
# # Keyword Extraction

# %% [markdown]
# ### Models using

# %% [markdown]
# #### 1. H1 extractor (code runs faster, ok ok keywords)---3-4mins
# #### 2. tech-keywords-extractor ( Code works good if given smaller chunks, execution takes time)---20mins
# #### 3. BART model by FB ( Should finetune with our data and can be used for question gen aswell )

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
import torch
import csv

def extract_keywords_batch(texts, max_length=100):
    inputs = tokenizer(texts, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        outputs = model.generate(**inputs, max_length=max_length)
    predicted_keywords = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return predicted_keywords

all_keywords = []

tokenizer = AutoTokenizer.from_pretrained("ilsilfverskiold/tech-keywords-extractor")
model = AutoModelForSeq2SeqLM.from_pretrained("ilsilfverskiold/tech-keywords-extractor")

batch_size = 10


csv_file = "extracted_keywords.csv"

with open(csv_file, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Original Sentence', 'Extracted Keywords'])

    for sentence in preprocessed_texts:
        sentence_parts = [sentence[i:i + max(1, int(len(sentence) / batch_size))] for i in range(0, len(sentence),
                                                                                        max(1, int(len(sentence) / batch_size)))]
        for part in sentence_parts:
            keywords = extract_keywords_batch(part, max_length=512)
            all_keywords.append(keywords.split())
            print("Extracted Keywords:", keywords)
            writer.writerow([sentence, keywords])

print("All Extracted Keywords:", all_keywords)
print(f"Keywords saved to {csv_file}")
# Out:
# From c:\Users\sriyo\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Extracted Keywords: Human Reproduction, Reproductive System
# Extracted Keywords: Human Reproductive Events, System Formation, Gametes, Sperms, Males
# Extracted Keywords: gametogenesis, ovum, sperms, genital tract insemination
# Extracted Keywords: le and female gametes fertilisation, zygote
# Extracted Keywords: Blastocyst Implantation, Uterine Wall, Embryo Development
# Extracted Keywords: Development Baby Parturition, Puberty
# Extracted Keywords: Parturition, Lactation Differences, Reproductive Events
# Extracted Keywords: Sperm Formation, Ovum
# Extracted Keywords: Male Reproductive Systems, Human Reproductive System
# Extracted Keywords: elvis region, testes, accessory ducts, external genitalia
# Extracted Keywords: 324
# Extracted Keywords: Human Reproduction, Testes, Scrotum
# Extracted Keywords: Testis, Spermatogenesis, Body Temperature
# Extracted Keywords: Testicular lobules, Male Pelvis, Reproductive System
# Extracted Keywords: Spermatogonia, Sertoli Cells, Sperms
# Extracted Keywords: Meiotic Divisions, Sertoli Cells, Sperm Formation
# Extracted Keywords: Ssels, Interstitial Cells, Leydig Cells, Testicular Hormones
# Extracted Keywords: androgens, male sex accessory ducts, vas deferens, seminiferous tu, immunologically competent cells
# Extracted Keywords: Testis, Vasa efferentia, epididymis
# Extracted Keywords: Vas deferens, seminal vesicle, urethra, ejaculatory duct
# Extracted Keywords: Urethra, Testis, Penis
# Extracted Keywords: 2324
# Extracted Keywords: biology, seminiferous tubule, penis
# Extracted Keywords: Glans Penis, Insemination
# Extracted Keywords: Male accessory glands, seminal vesicles, prostate, bulbourethral glands
# Extracted Keywords: se glands, bulbourethral glands, seminal plasma, fructose calcium, enzymes
# Extracted Keywords: lubrication of the penis. 2.2 t f r s he emale eproductive ystem, female reproductive system
# Extracted Keywords: Uterus, cervix vagina, mammary gland, pelvic region
# Extracted Keywords: Ovulation, Fertilisation, Pregnancy, Child Care
# Extracted Keywords: Female Sex organs, Steroid Hormones, Ovaries
# Extracted Keywords: Ovary, Pelvic Wall, Uterus
# Extracted Keywords: Ovarian Stroma, Endocrine System
# Extracted Keywords: 324
# Extracted Keywords: Human Reproduction, Figure 2.3
# Extracted Keywords: Female Pelvis, Oviducts, Reproductive System
# Extracted Keywords: ian tubes, vagina, female accessory
# Extracted Keywords: cts.org, Fallopian Tube
# Extracted Keywords: Ovary, Uterus
# Extracted Keywords: Ovary, Infundibulum
# Extracted Keywords: Infundibulum, Fingerlike projections
# Extracted Keywords: Ovum Collection, Fimbriae
# Extracted Keywords: Infundibulum, diagrammat
# Extracted Keywords: Female Reproductive System, Rationalis
# Extracted Keywords: ed 202324
# Extracted Keywords: Oviduct, ampulla, uterus
# Extracted Keywords: Uterus, Vagina, Ligaments
# Extracted Keywords: Cervical Canal, Vagina, Uterus
# Extracted Keywords: Endometrium, Menstrual Cycle
# Extracted Keywords: Myometrium, External Genitalia, Delivery
# Extracted Keywords: mons pubis, labia majora, vaginal ope
# Extracted Keywords: Clitoris, Labia Minora, Hymen
# Extracted Keywords: Hymen, Labia Minora, Urethral opening
# Extracted Keywords: Vaginal Tampon, Hymen
# Extracted Keywords: Oitus, Hymen, Mammary Gland
# Extracted Keywords: ed 202324
# Extracted Keywords: Mammary Glands, Human Reproduction
# Extracted Keywords: Mammary lobes, Alveoli, Milk Storage
# Extracted Keywords: Mammary Ducts, Testis, Ovaries, Ametogenesis
# Extracted Keywords: Testis, Ovum, Spermatogenesis
# Extracted Keywords: Spermatogonium, mitotic division, meiosis, seminiferous tubules
# Extracted Keywords: Meiotic Division Reduction, Secondary Spermatocytes, Haploid Cells
# Extracted Keywords: Haploid Spermatids, Spermiogenesis
# Extracted Keywords: Spermatogenesis, Sertoli Cells, seminiferous tubules
# Extracted Keywords: Gonadotropin, Gnrh, hypothalamic hormone, anterior pituitary gland
# Extracted Keywords: Follicle Stimulating Hormone, FSH, Spermatogenesis
# Extracted Keywords: Sperm, Spermiogenesis, Plasma Membrane
# Extracted Keywords: Sperm Head, Acrosome, Mitochondria
# Extracted Keywords: Human Male Ejaculation, Fertility
# Extracted Keywords: Sperm Tubules, Epidymis vas deferens, Prostate
# Extracted Keywords: Semen, Testicular Hormones, Oogenesis
# Extracted Keywords: Oogenesis, Spermatogenesis, Fetal Ovary
# Extracted Keywords: Primary Oocytes, Meiotic Division, Granulosa Cells
# Extracted Keywords: Ovary, Primary follicles, Secondary Follicles
# Extracted Keywords: Primary follicle, Antrum, Theca Layer
# Extracted Keywords: Primary Oocyte, tertiary follicle, meiotic division, haploid secondary oocyte
# Extracted Keywords: 24.24
# Extracted Keywords: Human Reproduction, Secondary Oocyte, Nutrient Rich Cytoplasm
# Extracted Keywords: Polar Body, Meiotic Division
# Extracted Keywords: Follicle Development, Graafian Follicle
# Extracted Keywords: yte, zona pellucida, graafian follicle, oocyte
# Extracted Keywords: vum, ovary, ovulation
# Extracted Keywords: Spermatogenesis, Oogenesis, Diagrammatic Representation
# Extracted Keywords: Spermatogenesis, Oogenesis, Fema
# Extracted Keywords: Menstruation, Monkeys, Apes, Human beings
# Extracted Keywords: Human Menstruation, Narche
# Extracted Keywords: Menstruation, Ovulation
# Extracted Keywords: 24.24
# Extracted Keywords: biology, menstrual cycle, diagrammatic presentation
# Extracted Keywords: Menstrual Cycle, Figure 2.9
# Extracted Keywords: Menstrual Flow, Break
# Extracted Keywords: Endometrial Lying, Uterus, Blood Vessels
# Extracted Keywords: Women, Menstruation
# Extracted Keywords: Pregnancy, Stress
# Extracted Keywords: Menstrual Phase, Follicular Phase, Health
# Extracted Keywords: Ovary, Graafian follicle, Endometriu
# Extracted Keywords: Uterus Regeneration, Proliferation
# Extracted Keywords: Pituitary, Ovarian Hormones, Rationalised
# Extracted Keywords: Human Reproduction, Gomadotropins, Follicular Hygiene
# Extracted Keywords: Lh Surge, Menstruation, Hygiene, Sanitation
# Extracted Keywords: elf ovulation, ovulatory phase, luteal phase, graafian follicle, sanitary napkins
# Extracted Keywords: Progesterone, Endometrium, Pregnancy
# Extracted Keywords: Endometrium, Sanitary Napkins, Fertilisation
# Extracted Keywords: Cyclic Menstruation, Menopause
# Extracted Keywords: Semen, Fertilisation, Implantation, Vagina Insemination
# Extracted Keywords: Fallopian tube, ampullary region, fertilisation
# Extracted Keywords: Fertilisation, Pregnancy
# Extracted Keywords: Acrosome, Ovum Fertilisation
# Extracted Keywords: ed 202324
# Extracted Keywords: biology membrane, meiotic division, secondary oocyte
# Extracted Keywords: Haploid Ovum, Sperms, diploid z
# Extracted Keywords: Zygote, Chromosomes, Sex
# Extracted Keywords: Chromosome Pattern, Human Female, Male
# Extracted Keywords: Sex Chromosome, Male Sperms
# Extracted Keywords: Sperm Fusion, Zygote
# Extracted Keywords: Chromosomal P, Ovum Development
# Extracted Keywords: atterns, mitoti, sex determination
# Extracted Keywords: c division, zygote, oviduct, uterus
# Extracted Keywords: Blastomeres, Ovum Fertilisation, Fallopian Tube
# Extracted Keywords: . 202324
# Extracted Keywords: Human Reproduction, Blastomeres, Morula Figure 2.11e
# Extracted Keywords: Endometrium, Trophoblast, Inner Cell Mass
# Extracted Keywords: Embryo Development, Endometrium, uterine Cells
# Extracted Keywords: antation, mbryonic evelopment, trophoblast, uterine tissue
# Extracted Keywords: Chorionic villi, uterine tissue, placenta
# Extracted Keywords: Placenta, Embryo
# Extracted Keywords: bilical cord, placenta, endocrine tissue
# Extracted Keywords: hcg hpl, relaxin, estrogens, progestogens, ovary
# Extracted Keywords: Estrogens, Progestogens, Prolactin thyroxine, Pregnancy
# Extracted Keywords: Fetal Growth, Metabolic Changes, Mother, Maintenance of Pregnancy
# Extracted Keywords: d 202324
# Extracted Keywords: Biology, Endoderm, Mesoderm
# Extracted Keywords: Human Embryo Development, Dogs, Elephants, Cats
# Extracted Keywords: Pregnancy, Embryo Development, Stethoscope
# Extracted Keywords: Fetus Development, Organ Systems, External Genital Organs
# Extracted Keywords: Human Pregnancy, Eyelashes, Parturition, Lactation
# Extracted Keywords: Parturition, Neuroendocrine Mechanism, Pregnancy
# Extracted Keywords: Oxytocin, Foetal Ejection
# Extracted Keywords: Uterine Contractions, Oxytocin, Placenta Expelling
# Extracted Keywords: Mammary Glands, Intrauterine Injections, Lactation
# Extracted Keywords: Lactation, Colostrum, Antibodies
# Extracted Keywords: ed 202324
# Extracted Keywords: Human Reproduction, Male Reproductive System
# Extracted Keywords: Seminiferous Tubules, Spermatogonia, Sertoli Cells, Leydig Cells
# Extracted Keywords: Sexal Reproductive System, Testicular Hormones, Androgens
# Extracted Keywords: Ovarian Hormones, Perimetrium, Endometrium, Vagina
# Extracted Keywords: Spermatogenesis, Female External Genitalia, Mammary Glands
# Extracted Keywords: Female Primates, Oogenesis, Menstrual Cycle
# Extracted Keywords: Menstrual Cycle, Pituitary Hormones, Ovum
# Extracted Keywords: Diploid Zygote, Blastocyst, Y chromosome
# Extracted Keywords: Parturition, Breastfeeding, Neuroendocrine Mechanism, Cortisol, Oxytocin
# Extracted Keywords: Human Reproduction, Diploid Haploid
# Extracted Keywords: 2324
# Extracted Keywords: Ovulation, Hormone, Fertilisation
# Extracted Keywords: Foetus, Uterus, vascular connection, male reproductive system, female reproductive system
# Extracted Keywords: Spermatogenesis, Testis, Ovary, Hormones
# Extracted Keywords: Spermatogenesis, Spermiation, Male Accessories
# Extracted Keywords: Oogenesis, Graafian follicle, corpus luteum b endometr
# Extracted Keywords: Spermatozoa, Sertoli Cells, Acrosome, Fimbriae
# Extracted Keywords: Leydig Cells, Oogenesis, Androgens
# Extracted Keywords: Hymen, Menstrual Cycle, Parturition
# Extracted Keywords: Human Ovary, Female Infertility
# Extracted Keywords: Identical Twins, Fraternal Twins
# Extracted Keywords: 202324
# All Extracted Keywords: [['Human', 'Reproduction,', 'Reproductive', 'System'], ['Human', 'Reproductive', 'Events,', 'System', 'Formation,', 'Gametes,', 'Sperms,', 'Males'], ['gametogenesis,', 'ovum,', 'sperms,', 'genital', 'tract', 'insemination'], ['le', 'and', 'female', 'gametes', 'fertilisation,', 'zygote'], ['Blastocyst', 'Implantation,', 'Uterine', 'Wall,', 'Embryo', 'Development'], ['Development', 'Baby', 'Parturition,', 'Puberty'], ['Parturition,', 'Lactation', 'Differences,', 'Reproductive', 'Events'], ['Sperm', 'Formation,', 'Ovum'], ['Male', 'Reproductive', 'Systems,', 'Human', 'Reproductive', 'System'], ['elvis', 'region,', 'testes,', 'accessory', 'ducts,', 'external', 'genitalia'], ['324'], ['Human', 'Reproduction,', 'Testes,', 'Scrotum'], ['Testis,', 'Spermatogenesis,', 'Body', 'Temperature'], ['Testicular', 'lobules,', 'Male', 'Pelvis,', 'Reproductive', 'System'], ['Spermatogonia,', 'Sertoli', 'Cells,', 'Sperms'], ['Meiotic', 'Divisions,', 'Sertoli', 'Cells,', 'Sperm', 'Formation'], ['Ssels,', 'Interstitial', 'Cells,', 'Leydig', 'Cells,', 'Testicular', 'Hormones'], ['androgens,', 'male', 'sex', 'accessory', 'ducts,', 'vas', 'deferens,', 'seminiferous', 'tu,', 'immunologically', 'competent', 'cells'], ['Testis,', 'Vasa', 'efferentia,', 'epididymis'], ['Vas', 'deferens,', 'seminal', 'vesicle,', 'urethra,', 'ejaculatory', 'duct'], ['Urethra,', 'Testis,', 'Penis'], ['2324'], ['biology,', 'seminiferous', 'tubule,', 'penis'], ['Glans', 'Penis,', 'Insemination'], ['Male', 'accessory', 'glands,', 'seminal', 'vesicles,', 'prostate,', 'bulbourethral', 'glands'], ['se', 'glands,', 'bulbourethral', 'glands,', 'seminal', 'plasma,', 'fructose', 'calcium,', 'enzymes'], ['lubrication', 'of', 'the', 'penis.', '2.2', 't', 'f', 'r', 's', 'he', 'emale', 'eproductive', 'ystem,', 'female', 'reproductive', 'system'], ['Uterus,', 'cervix', 'vagina,', 'mammary', 'gland,', 'pelvic', 'region'], ['Ovulation,', 'Fertilisation,', 'Pregnancy,', 'Child', 'Care'], ['Female', 'Sex', 'organs,', 'Steroid', 'Hormones,', 'Ovaries'], ['Ovary,', 'Pelvic', 'Wall,', 'Uterus'], ['Ovarian', 'Stroma,', 'Endocrine', 'System'], ['324'], ['Human', 'Reproduction,', 'Figure', '2.3'], ['Female', 'Pelvis,', 'Oviducts,', 'Reproductive', 'System'], ['ian', 'tubes,', 'vagina,', 'female', 'accessory'], ['cts.org,', 'Fallopian', 'Tube'], ['Ovary,', 'Uterus'], ['Ovary,', 'Infundibulum'], ['Infundibulum,', 'Fingerlike', 'projections'], ['Ovum', 'Collection,', 'Fimbriae'], ['Infundibulum,', 'diagrammat'], ['Female', 'Reproductive', 'System,', 'Rationalis'], ['ed', '202324'], ['Oviduct,', 'ampulla,', 'uterus'], ['Uterus,', 'Vagina,', 'Ligaments'], ['Cervical', 'Canal,', 'Vagina,', 'Uterus'], ['Endometrium,', 'Menstrual', 'Cycle'], ['Myometrium,', 'External', 'Genitalia,', 'Delivery'], ['mons', 'pubis,', 'labia', 'majora,', 'vaginal', 'ope'], ['Clitoris,', 'Labia', 'Minora,', 'Hymen'], ['Hymen,', 'Labia', 'Minora,', 'Urethral', 'opening'], ['Vaginal', 'Tampon,', 'Hymen'], ['Oitus,', 'Hymen,', 'Mammary', 'Gland'], ['ed', '202324'], ['Mammary', 'Glands,', 'Human', 'Reproduction'], ['Mammary', 'lobes,', 'Alveoli,', 'Milk', 'Storage'], ['Mammary', 'Ducts,', 'Testis,', 'Ovaries,', 'Ametogenesis'], ['Testis,', 'Ovum,', 'Spermatogenesis'], ['Spermatogonium,', 'mitotic', 'division,', 'meiosis,', 'seminiferous', 'tubules'], ['Meiotic', 'Division', 'Reduction,', 'Secondary', 'Spermatocytes,', 'Haploid', 'Cells'], ['Haploid', 'Spermatids,', 'Spermiogenesis'], ['Spermatogenesis,', 'Sertoli', 'Cells,', 'seminiferous', 'tubules'], ['Gonadotropin,', 'Gnrh,', 'hypothalamic', 'hormone,', 'anterior', 'pituitary', 'gland'], ['Follicle', 'Stimulating', 'Hormone,', 'FSH,', 'Spermatogenesis'], ['Sperm,', 'Spermiogenesis,', 'Plasma', 'Membrane'], ['Sperm', 'Head,', 'Acrosome,', 'Mitochondria'], ['Human', 'Male', 'Ejaculation,', 'Fertility'], ['Sperm', 'Tubules,', 'Epidymis', 'vas', 'deferens,', 'Prostate'], ['Semen,', 'Testicular', 'Hormones,', 'Oogenesis'], ['Oogenesis,', 'Spermatogenesis,', 'Fe ...
# Keywords saved to extracted_keywords.csv

# %%
all_keywords_hi=[]
for i in all_keywords:
    for j in i:
        all_keywords_hi.append(j)

# %%
all_keywords
# Out:
# [['Human', 'Reproduction,', 'Reproductive', 'System'],
#  ['Human',
#   'Reproductive',
#   'Events,',
#   'System',
#   'Formation,',
#   'Gametes,',
#   'Sperms,',
#   'Males'],
#  ['gametogenesis,', 'ovum,', 'sperms,', 'genital', 'tract', 'insemination'],
#  ['le', 'and', 'female', 'gametes', 'fertilisation,', 'zygote'],
#  ['Blastocyst', 'Implantation,', 'Uterine', 'Wall,', 'Embryo', 'Development'],
#  ['Development', 'Baby', 'Parturition,', 'Puberty'],
#  ['Parturition,', 'Lactation', 'Differences,', 'Reproductive', 'Events'],
#  ['Sperm', 'Formation,', 'Ovum'],
#  ['Male', 'Reproductive', 'Systems,', 'Human', 'Reproductive', 'System'],
#  ['elvis',
#   'region,',
#   'testes,',
#   'accessory',
#   'ducts,',
#   'external',
#   'genitalia'],
#  ['324'],
#  ['Human', 'Reproduction,', 'Testes,', 'Scrotum'],
#  ['Testis,', 'Spermatogenesis,', 'Body', 'Temperature'],
#  ['Testicular', 'lobules,', 'Male', 'Pelvis,', 'Reproductive', 'System'],
#  ['Spermatogonia,', 'Sertoli', 'Cells,', 'Sperms'],
#  ['Meiotic', 'Divisions,', 'Sertoli', 'Cells,', 'Sperm', 'Formation'],
#  ['Ssels,',
#   'Interstitial',
#   'Cells,',
#   'Leydig',
#   'Cells,',
#   'Testicular',
#   'Hormones'],
#  ['androgens,',
#   'male',
#   'sex',
#   'accessory',
#   'ducts,',
#   'vas',
#   'deferens,',
#   'seminiferous',
#   'tu,',
#   'immunologically',
#   'competent',
#   'cells'],
#  ['Testis,', 'Vasa', 'efferentia,', 'epididymis'],
#  ['Vas',
#   'deferens,',
#   'seminal',
#   'vesicle,',
#   'urethra,',
#   'ejaculatory',
#   'duct'],
#  ['Urethra,', 'Testis,', 'Penis'],
#  ['2324'],
#  ['biology,', 'seminiferous', 'tubule,', 'penis'],
#  ['Glans', 'Penis,', 'Insemination'],
#  ['Male',
#   'accessory',
#   'glands,',
#   'seminal',
#   'vesicles,',
#   'prostate,',
#   'bulbourethral',
#   'glands'],
#  ['se',
#   'glands,',
#   'bulbourethral',
#   'glands,',
#   'seminal',
#   'plasma,',
#   'fructose',
#   'calcium,',
#   'enzymes'],
#  ['lubrication',
#   'of',
#   'the',
#   'penis.',
#   '2.2',
#   't',
#   'f',
#   'r',
#   's',
#   'he',
#   'emale',
#   'eproductive',
#   'ystem,',
#   'female',
#   'reproductive',
#   'system'],
#  ['Uterus,', 'cervix', 'vagina,', 'mammary', 'gland,', 'pelvic', 'region'],
#  ['Ovulation,', 'Fertilisation,', 'Pregnancy,', 'Child', 'Care'],
#  ['Female', 'Sex', 'organs,', 'Steroid', 'Hormones,', 'Ovaries'],
#  ['Ovary,', 'Pelvic', 'Wall,', 'Uterus'],
#  ['Ovarian', 'Stroma,', 'Endocrine', 'System'],
#  ['324'],
#  ['Human', 'Reproduction,', 'Figure', '2.3'],
#  ['Female', 'Pelvis,', 'Oviducts,', 'Reproductive', 'System'],
#  ['ian', 'tubes,', 'vagina,', 'female', 'accessory'],
#  ['cts.org,', 'Fallopian', 'Tube'],
#  ['Ovary,', 'Uterus'],
#  ['Ovary,', 'Infundibulum'],
#  ['Infundibulum,', 'Fingerlike', 'projections'],
#  ['Ovum', 'Collection,', 'Fimbriae'],
#  ['Infundibulum,', 'diagrammat'],
#  ['Female', 'Reproductive', 'System,', 'Rationalis'],
#  ['ed', '202324'],
#  ['Oviduct,', 'ampulla,', 'uterus'],
#  ['Uterus,', 'Vagina,', 'Ligaments'],
#  ['Cervical', 'Canal,', 'Vagina,', 'Uterus'],
#  ['Endometrium,', 'Menstrual', 'Cycle'],
#  ['Myometrium,', 'External', 'Genitalia,', 'Delivery'],
#  ['mons', 'pubis,', 'labia', 'majora,', 'vaginal', 'ope'],
#  ['Clitoris,', 'Labia', 'Minora,', 'Hymen'],
#  ['Hymen,', 'Labia', 'Minora,', 'Urethral', 'opening'],
#  ['Vaginal', 'Tampon,', 'Hymen'],
#  ['Oitus,', 'Hymen,', 'Mammary', 'Gland'],
#  ['ed', '202324'],
#  ['Mammary', 'Glands,', 'Human', 'Reproduction'],
#  ['Mammary', 'lobes,', 'Alveoli,', 'Milk', 'Storage'],
#  ['Mammary', 'Ducts,', 'Testis,', 'Ovaries,', 'Ametogenesis'],
#  ['Testis,', 'Ovum,', 'Spermatogenesis'],
#  ['Spermatogonium,',
#   'mitotic',
#   'division,',
#   'meiosis,',
#   'seminiferous',
#   'tubules'],
#  ['Meiotic',
#   'Division',
#   'Reduction,',
#   'Secondary',
#   'Spermatocytes,',
#   'Haploid',
#   'Cells'],
#  ['Haploid', 'Spermatids,', 'Spermiogenesis'],
#  ['Spermatogenesis,', 'Sertoli', 'Cells,', 'seminiferous', 'tubules'],
#  ['Gonadotropin,',
#   'Gnrh,',
#   'hypothalamic',
#   'hormone,',
#   'anterior',
#   'pituitary',
#   'gland'],
#  ['Follicle', 'Stimulating', 'Hormone,', 'FSH,', 'Spermatogenesis'],
#  ['Sperm,', 'Spermiogenesis,', 'Plasma', 'Membrane'],
#  ['Sperm', 'Head,', 'Acrosome,', 'Mitochondria'],
#  ['Human', 'Male', 'Ejaculation,', 'Fertility'],
#  ['Sperm', 'Tubules,', 'Epidymis', 'vas', 'deferens,', 'Prostate'],
#  ['Semen,', 'Testicular', 'Hormones,', 'Oogenesis'],
#  ['Oogenesis,', 'Spermatogenesis,', 'Fetal', 'Ovary'],
#  ['Primary', 'Oocytes,', 'Meiotic', 'Division,', 'Granulosa', 'Cells'],
#  ['Ovary,', 'Primary', 'follicles,', 'Secondary', 'Follicles'],
#  ['Primary', 'follicle,', 'Antrum,', 'Theca', 'Layer'],
#  ['Primary',
#   'Oocyte,',
#   'tertiary',
#   'follicle,',
#   'meiotic',
#   'division,',
#   'haploid',
#   'secondary',
#   'oocyte'],
#  ['24.24'],
#  ['Human',
#   'Reproduction,',
#   'Secondary',
#   'Oocyte,',
#   'Nutrient',
#   'Rich',
#   'Cytoplasm'],
#  ['Polar', 'Body,', 'Meiotic', 'Division'],
#  ['Follicle', 'Development,', 'Graafian', 'Follicle'],
#  ['yte,', 'zona', 'pellucida,', 'graafian', 'follicle,', 'oocyte'],
#  ['vum,', 'ovary,', 'ovulation'],
#  ['Spermatogenesis,', 'Oogenesis,', 'Diagrammatic', 'Representation'],
#  ['Spermatogenesis,', 'Oogenesis,', 'Fema'],
#  ['Menstruation,', 'Monkeys,', 'Apes,', 'Human', 'beings'],
#  ['Human', 'Menstruation,', 'Narche'],
#  ['Menstruation,', 'Ovulation'],
#  ['24.24'],
#  ['biology,', 'menstrual', 'cycle,', 'diagrammatic', 'presentation'],
#  ['Menstrual', 'Cycle,', 'Figure', '2.9'],
#  ['Menstrual', 'Flow,', 'Break'],
#  ['Endometrial', 'Lying,', 'Uterus,', 'Blood', 'Vessels'],
#  ['Women,', 'Menstruation'],
#  ['Pregnancy,', 'Stress'],
#  ['Menstrual', 'Phase,', 'Follicular', 'Phase,', 'Health'],
#  ['Ovary,', 'Graafian', 'follicle,', 'Endometriu'],
#  ['Uterus', 'Regeneration,', 'Proliferation'],
#  ['Pituitary,', 'Ovarian', 'Hormones,', 'Rationalised'],
#  ['Human', 'Reproduction,', 'Gomadotropins,', 'Follicular', 'Hygiene'],
#  ['Lh', 'Surge,', 'Menstruation,', 'Hygiene,', 'Sanitation'],
#  ['elf',
#   'ovulation,',
#   'ovulatory',
#   'phase,',
#   'luteal',
#   'phase,',
#   'graafian',
#   'follicle,',
#   'sanitary',
#   'napkins'],
#  ['Progesterone,', 'Endometrium,', 'Pregnancy'],
#  ['Endometrium,', 'Sanitary', 'Napkins,', 'Fertilisation'],
#  ['Cyclic', 'Menstruation,', 'Menopause'],
#  ['Semen,', 'Fertilisation,', 'Implantation,', 'Vagina', 'Insemination'],
#  ['Fallopian', 'tube,', 'ampullary', 'region,', 'fertilisation'],
#  ['Fertilisation,', 'Pregnancy'],
#  ['Acrosome,', 'Ovum', 'Fertilisation'],
#  ['ed', '202324'],
#  ['biology', 'membrane,', 'meiotic', 'division,', 'secondary', 'oocyte'],
#  ['Haploid', 'Ovum,', 'Sperms,', 'diploid', 'z'],
#  ['Zygote,', 'Chromosomes,', 'Sex'],
#  ['Chromosome', 'Pattern,', 'Human', 'Female,', 'Male'],
#  ['Sex', 'Chromosome,', 'Male', 'Sperms'],
#  ['Sperm', 'Fusion,', 'Zygote'],
#  ['Chromosomal', 'P,', 'Ovum', 'Development'],
#  ['atterns,', 'mitoti,', 'sex', 'determination'],
#  ['c', 'division,', 'zygote,', 'oviduct,', 'uterus'],
#  ['Blastomeres,', 'Ovum', 'Fertilisation,', 'Fallopian', 'Tube'],
#  ['.', '202324'],
#  ['Human', 'Reproduction,', 'Blastomeres,', 'Morula', 'Figure', '2.11e'],
#  ['Endometrium,', 'Trophoblast,', 'Inner', 'Cell', 'Mass'],
#  ['Embryo', 'Development,', 'Endometrium,', 'uterine', 'Cells'],
#  ['antation,', 'mbryonic', 'evelopment,', 'trophoblast,', 'uterine', 'tissue'],
#  ['Chorionic', 'villi,', 'uterine', 'tissue,', 'placenta'],
#  ['Placenta,', 'Embryo'],
#  ['bilical', 'cord,', 'placenta,', 'endocrine', 'tissue'],
#  ['hcg', 'hpl,', 'relaxin,', 'estrogens,', 'progestogens,', 'ovary'],
#  ['Estrogens,', 'Progestogens,', 'Prolactin', 'thyroxine,', 'Pregnancy'],
#  ['Fetal',
#   'Growth,',
#   'Metabolic',
#   'Changes,',
#   'Mother,',
#   'Maintenance',
#   'of',
#   'Pregnancy'],
#  ['d', '202324'],
#  ['Biology,', 'Endoderm,', 'Mesoderm'],
#  ['Human', 'Embryo', 'Development,', 'Dogs,', 'Elephants,', 'Cats'],
#  ['Pregnancy,', 'Embryo', 'Development,', 'Stethoscope'],
#  ['Fetus',
#   'Development,',
#   'Organ',
#   'Systems,',
#   'External',
#   'Genital',
#   'Organs'],
#  ['Human', 'Pregnancy,', 'Eyelashes,', 'Parturition,', 'Lactation'],
#  ['Parturition,', 'Neuroendocrine', 'Mechanism,', 'Pregnancy'],
#  ['Oxytocin,', 'Foetal', 'Ejection'],
#  ['Uterine', 'Contractions,', 'Oxytocin,', 'Placenta', 'Expelling'],
#  ['Mammary', 'Glands,', 'Intrauterine', 'Injections,', 'Lactation'],
#  ['Lactation,', 'Colostrum,', 'Antibodies'],
#  ['ed', '202324'],
#  ['Human', 'Reproduction,', 'Male', 'Reproductive', 'System'],
#  ['Seminiferous',
#   'Tubules,',
#   'Spermatogonia,',
#   'Sertoli',
#   'Cells,',
#   'Leydig',
#   'Cells'],
#  ['Sexal', 'Reproductive', 'System,', 'Testicular', 'Hormones,', 'Androgens'],
#  ['Ovarian', 'Hormones,', 'Perimetrium,', 'Endometrium,', 'Vagina'],
#  ['Spermatogenesis,', 'Female', 'External', 'Genitalia,', 'Mammary', 'Glands'],
#  ['Female', 'Primates,', 'Oogenesis,', 'Menstrual', 'Cycle'],
#  ['Menstrual', 'Cycle,', 'Pituitary', 'Hormones,', 'Ovum'],
#  ['Diploid', 'Zygote,', 'Blastocyst,', 'Y', 'chromosome'],
#  ['Parturition,',
#   'Breastfeeding,',
#   'Neuroendocrine',
#   'Mechanism,',
#   'Cortisol,',
#   'Oxytocin'],
#  ['Human', 'Reproduction,', 'Diploid', 'Haploid'],
#  ['2324'],
#  ['Ovulation,', 'Hormone,', 'Fertilisation'],
#  ['Foetus,',
#   'Uterus,',
#   'vascular',
#   'connection,',
#   'male',
#   'reproductive',
#   'system,',
#   'female',
#   'reproductive',
#   'system'],
#  ['Spermatogenesis,', 'Testis,', 'Ovary,', 'Hormones'],
#  ['Spermatogenesis,', 'Spermiation,', 'Male', 'Accessories'],
#  ['Oogenesis,', 'Graafian', 'follicle,', 'corpus', 'luteum', 'b', 'endometr'],
#  ['Spermatozoa,', 'Sertoli', 'Cells,', 'Acrosome,', 'Fimbriae'],
#  ['Leydig', 'Cells,', 'Oogenesis,', 'Androgens'],
#  ['Hymen,', 'Menstrual', 'Cycle,', 'Parturition'],
#  ['Human', 'Ovary,', 'Female', 'Infertility'],
#  ['Identical', 'Twins,', 'Fraternal', 'Twins'],
#  ['202324']]

# %%
len(all_keywords_hi)
# Out:
# 738

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def filter_keywords_spacy(keywords):
    doc = nlp(" ".join(keywords))

    filtered_keywords = []
    removed_keywords = []

    for token in doc:
        if (
            not token.is_stop
            and not token.is_punct
            and not any(char.isdigit() for char in token.text)
            and token.text.lower() != 'figure'
            and token.text.lower() != 'diagram'
            and len(token.text) >= 3  
        ):
            filtered_keywords.append(token.text)
        else:
            removed_keywords.append(token.text)

    return filtered_keywords, removed_keywords

filtered_keywords_spacy, removed_keywords_spacy = filter_keywords_spacy(all_keywords_hi)

print("Filtered Keywords (spaCy):", filtered_keywords_spacy)
print("Removed Keywords (spaCy):", removed_keywords_spacy)
# Out:
# Filtered Keywords (spaCy): ['Human', 'Reproduction', 'Reproductive', 'System', 'Human', 'Reproductive', 'Events', 'System', 'Formation', 'Gametes', 'Sperms', 'Males', 'gametogenesis', 'ovum', 'sperms', 'genital', 'tract', 'insemination', 'female', 'gametes', 'fertilisation', 'zygote', 'Blastocyst', 'Implantation', 'Uterine', 'Wall', 'Embryo', 'Development', 'Development', 'Baby', 'Parturition', 'Puberty', 'Parturition', 'Lactation', 'Differences', 'Reproductive', 'Events', 'Sperm', 'Formation', 'Ovum', 'Male', 'Reproductive', 'Systems', 'Human', 'Reproductive', 'System', 'elvis', 'region', 'testes', 'accessory', 'ducts', 'external', 'genitalia', 'Human', 'Reproduction', 'Testes', 'Scrotum', 'Testis', 'Spermatogenesis', 'Body', 'Temperature', 'Testicular', 'lobules', 'Male', 'Pelvis', 'Reproductive', 'System', 'Spermatogonia', 'Sertoli', 'Cells', 'Sperms', 'Meiotic', 'Divisions', 'Sertoli', 'Cells', 'Sperm', 'Formation', 'Ssels', 'Interstitial', 'Cells', 'Leydig', 'Cells', 'Testicular', 'Hormones', 'androgens', 'male', 'sex', 'accessory', 'ducts', 'vas', 'deferens', 'seminiferous', 'immunologically', 'competent', 'cells', 'Testis', 'Vasa', 'efferentia', 'epididymis', 'Vas', 'deferens', 'seminal', 'vesicle', 'urethra', 'ejaculatory', 'duct', 'Urethra', 'Testis', 'Penis', 'biology', 'seminiferous', 'tubule', 'penis', 'Glans', 'Penis', 'Insemination', 'Male', 'accessory', 'glands', 'seminal', 'vesicles', 'prostate', 'bulbourethral', 'glands', 'glands', 'bulbourethral', 'glands', 'seminal', 'plasma', 'fructose', 'calcium', 'enzymes', 'lubrication', 'penis', 'emale', 'eproductive', 'ystem', 'female', 'reproductive', 'system', 'Uterus', 'cervix', 'vagina', 'mammary', 'gland', 'pelvic', 'region', 'Ovulation', 'Fertilisation', 'Pregnancy', 'Child', 'Care', 'Female', 'Sex', 'organs', 'Steroid', 'Hormones', 'Ovaries', 'Ovary', 'Pelvic', 'Wall', 'Uterus', 'Ovarian', 'Stroma', 'Endocrine', 'System', 'Human', 'Reproduction', 'Female', 'Pelvis', 'Oviducts', 'Reproductive', 'System', 'ian', 'tubes', 'vagina', 'female', 'accessory', 'cts.org', 'Fallopian', 'Tube', 'Ovary', 'Uterus', 'Ovary', 'Infundibulum', 'Infundibulum', 'Fingerlike', 'projections', 'Ovum', 'Collection', 'Fimbriae', 'Infundibulum', 'diagrammat', 'Female', 'Reproductive', 'System', 'Rationalis', 'Oviduct', 'ampulla', 'uterus', 'Uterus', 'Vagina', 'Ligaments', 'Cervical', 'Canal', 'Vagina', 'Uterus', 'Endometrium', 'Menstrual', 'Cycle', 'Myometrium', 'External', 'Genitalia', 'Delivery', 'mons', 'pubis', 'labia', 'majora', 'vaginal', 'ope', 'Clitoris', 'Labia', 'Minora', 'Hymen', 'Hymen', 'Labia', 'Minora', 'Urethral', 'opening', 'Vaginal', 'Tampon', 'Hymen', 'Oitus', 'Hymen', 'Mammary', 'Gland', 'Mammary', 'Glands', 'Human', 'Reproduction', 'Mammary', 'lobes', 'Alveoli', 'Milk', 'Storage', 'Mammary', 'Ducts', 'Testis', 'Ovaries', 'Ametogenesis', 'Testis', 'Ovum', 'Spermatogenesis', 'Spermatogonium', 'mitotic', 'division', 'meiosis', 'seminiferous', 'tubules', 'Meiotic', 'Division', 'Reduction', 'Secondary', 'Spermatocytes', 'Haploid', 'Cells', 'Haploid', 'Spermatids', 'Spermiogenesis', 'Spermatogenesis', 'Sertoli', 'Cells', 'seminiferous', 'tubules', 'Gonadotropin', 'Gnrh', 'hypothalamic', 'hormone', 'anterior', 'pituitary', 'gland', 'Follicle', 'Stimulating', 'Hormone', 'FSH', 'Spermatogenesis', 'Sperm', 'Spermiogenesis', 'Plasma', 'Membrane', 'Sperm', 'Head', 'Acrosome', 'Mitochondria', 'Human', 'Male', 'Ejaculation', 'Fertility', 'Sperm', 'Tubules', 'Epidymis', 'vas', 'deferens', 'Prostate', 'Semen', 'Testicular', 'Hormones', 'Oogenesis', 'Oogenesis', 'Spermatogenesis', 'Fetal', 'Ovary', 'Primary', 'Oocytes', 'Meiotic', 'Division', 'Granulosa', 'Cells', 'Ovary', 'Primary', 'follicles', 'Secondary', 'Follicles', 'Primary', 'follicle', 'Antrum', 'Theca', 'Layer', 'Primary', 'Oocyte', 'tertiary', 'follicle', 'meiotic', 'division', 'haploid', 'secondary', 'oocyte', 'Human', 'Reproduction', 'Secondary', 'Oocyte', 'Nutrient', 'Rich', 'Cytoplasm', 'Polar', 'Body', 'Meiotic', 'Divi ...
# Removed Keywords (spaCy): [',', ',', ',', ',', ',', ',', ',', ',', 'le', 'and', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', '324', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'tu', ',', ',', ',', ',', ',', ',', ',', ',', '2324', ',', ',', ',', ',', ',', ',', 'se', ',', ',', ',', ',', 'of', 'the', '.', '2.2', 't', 'f', 'r', 's', 'he', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', '324', ',', 'Figure', '2.3', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'ed', '202324', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'ed', '202324', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', '24.24', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', '24.24', ',', ',', ',', 'Figure', '2.9', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'Lh', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'ed', '202324', ',', ',', ',', ',', 'z', ',', ',', ',', ',', ',', ',', 'P', ',', ',', ',', 'c', ',', ',', ',', ',', ',', '.', '202324', ',', ',', 'Figure', '2.11e', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'of', 'd', '202324', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'ed', '202324', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'Y', ',', ',', ',', ',', ',', '2324', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', ',', 'b', ',', ',', ',', ',', ',', ',', ',', ',', ',', '202324']

# %%
filtered_keywords_spaci=[]
for i in filtered_keywords_spacy:
    if i.lower() not in filtered_keywords_spaci:
        filtered_keywords_spaci.append(i.lower())

# %%
len(filtered_keywords_spaci)
# Out:
# 303

# %%
filtered_keywords_spaci
# Out:
# ['human',
#  'reproduction',
#  'reproductive',
#  'system',
#  'events',
#  'formation',
#  'gametes',
#  'sperms',
#  'males',
#  'gametogenesis',
#  'ovum',
#  'genital',
#  'tract',
#  'insemination',
#  'female',
#  'fertilisation',
#  'zygote',
#  'blastocyst',
#  'implantation',
#  'uterine',
#  'wall',
#  'embryo',
#  'development',
#  'baby',
#  'parturition',
#  'puberty',
#  'lactation',
#  'differences',
#  'sperm',
#  'male',
#  'systems',
#  'elvis',
#  'region',
#  'testes',
#  'accessory',
#  'ducts',
#  'external',
#  'genitalia',
#  'scrotum',
#  'testis',
#  'spermatogenesis',
#  'body',
#  'temperature',
#  'testicular',
#  'lobules',
#  'pelvis',
#  'spermatogonia',
#  'sertoli',
#  'cells',
#  'meiotic',
#  'divisions',
#  'ssels',
#  'interstitial',
#  'leydig',
#  'hormones',
#  'androgens',
#  'sex',
#  'vas',
#  'deferens',
#  'seminiferous',
#  'immunologically',
#  'competent',
#  'vasa',
#  'efferentia',
#  'epididymis',
#  'seminal',
#  'vesicle',
#  'urethra',
#  'ejaculatory',
#  'duct',
#  'penis',
#  'biology',
#  'tubule',
#  'glans',
#  'glands',
#  'vesicles',
#  'prostate',
#  'bulbourethral',
#  'plasma',
#  'fructose',
#  'calcium',
#  'enzymes',
#  'lubrication',
#  'emale',
#  'eproductive',
#  'ystem',
#  'uterus',
#  'cervix',
#  'vagina',
#  'mammary',
#  'gland',
#  'pelvic',
#  'ovulation',
#  'pregnancy',
#  'child',
#  'care',
#  'organs',
#  'steroid',
#  'ovaries',
#  'ovary',
#  'ovarian',
#  'stroma',
#  'endocrine',
#  'oviducts',
#  'ian',
#  'tubes',
#  'cts.org',
#  'fallopian',
#  'tube',
#  'infundibulum',
#  'fingerlike',
#  'projections',
#  'collection',
#  'fimbriae',
#  'diagrammat',
#  'rationalis',
#  'oviduct',
#  'ampulla',
#  'ligaments',
#  'cervical',
#  'canal',
#  'endometrium',
#  'menstrual',
#  'cycle',
#  'myometrium',
#  'delivery',
#  'mons',
#  'pubis',
#  'labia',
#  'majora',
#  'vaginal',
#  'ope',
#  'clitoris',
#  'minora',
#  'hymen',
#  'urethral',
#  'opening',
#  'tampon',
#  'oitus',
#  'lobes',
#  'alveoli',
#  'milk',
#  'storage',
#  'ametogenesis',
#  'spermatogonium',
#  'mitotic',
#  'division',
#  'meiosis',
#  'tubules',
#  'reduction',
#  'secondary',
#  'spermatocytes',
#  'haploid',
#  'spermatids',
#  'spermiogenesis',
#  'gonadotropin',
#  'gnrh',
#  'hypothalamic',
#  'hormone',
#  'anterior',
#  'pituitary',
#  'follicle',
#  'stimulating',
#  'fsh',
#  'membrane',
#  'head',
#  'acrosome',
#  'mitochondria',
#  'ejaculation',
#  'fertility',
#  'epidymis',
#  'semen',
#  'oogenesis',
#  'fetal',
#  'primary',
#  'oocytes',
#  'granulosa',
#  'follicles',
#  'antrum',
#  'theca',
#  'layer',
#  'oocyte',
#  'tertiary',
#  'nutrient',
#  'rich',
#  'cytoplasm',
#  'polar',
#  'graafian',
#  'yte',
#  'zona',
#  'pellucida',
#  'vum',
#  'diagrammatic',
#  'representation',
#  'fema',
#  'menstruation',
#  'monkeys',
#  'apes',
#  'beings',
#  'narche',
#  'presentation',
#  'flow',
#  'break',
#  'endometrial',
#  'lying',
#  'blood',
#  'vessels',
#  'women',
#  'stress',
#  'phase',
#  'follicular',
#  'health',
#  'endometriu',
#  'regeneration',
#  'proliferation',
#  'rationalised',
#  'gomadotropins',
#  'hygiene',
#  'surge',
#  'sanitation',
#  'elf',
#  'ovulatory',
#  'luteal',
#  'sanitary',
#  'napkins',
#  'progesterone',
#  'cyclic',
#  'menopause',
#  'ampullary',
#  'diploid',
#  'chromosomes',
#  'chromosome',
#  'pattern',
#  'fusion',
#  'chromosomal',
#  'atterns',
#  'mitoti',
#  'determination',
#  'blastomeres',
#  'morula',
#  'trophoblast',
#  'inner',
#  'cell',
#  'mass',
#  'antation',
#  'mbryonic',
#  'evelopment',
#  'tissue',
#  'chorionic',
#  'villi',
#  'placenta',
#  'bilical',
#  'cord',
#  'hcg',
#  'hpl',
#  'relaxin',
#  'estrogens',
#  'progestogens',
#  'prolactin',
#  'thyroxine',
#  'growth',
#  'metabolic',
#  'changes',
#  'mother',
#  'maintenance',
#  'endoderm',
#  'mesoderm',
#  'dogs',
#  'elephants',
#  'cats',
#  'stethoscope',
#  'fetus',
#  'organ',
#  'eyelashes',
#  'neuroendocrine',
#  'mechanism',
#  'oxytocin',
#  'foetal',
#  'ejection',
#  'contractions',
#  'expelling',
#  'intrauterine',
#  'injections',
#  'colostrum',
#  'antibodies',
#  'sexal',
#  'perimetrium',
#  'primates',
#  'breastfeeding',
#  'cortisol',
#  'foetus',
#  'vascular',
#  'connection',
#  'spermiation',
#  'accessories',
#  'corpus',
#  'luteum',
#  'endometr',
#  'spermatozoa',
#  'infertility',
#  'identical',
#  'twins',
#  'fraternal']

# %% [markdown]
# # Filtration using Keywords

# %%
import csv

def save_to_csv(file_path, data):
    with open(file_path, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file)
        writer.writerow(['Question'])

        for item in data:
            cleaned_question = item
            writer.writerow([cleaned_question])


def filter_questions_by_context(questions, context_keywords):
    filtered_questions = []
    keyword_out = []
    for question in questions:
        if any(keyword in question.lower() for keyword in context_keywords):
            filtered_questions.append(question)
        else:
            keyword_out.append(question)
    return filtered_questions, keyword_out

filtered_questions, keyword_out = filter_questions_by_context(generated_questions, filtered_keywords_spaci)

# Save filtered questions to CSV
save_to_csv("filtered_questions.csv", filtered_questions)

# Save questions filtered out to CSV
save_to_csv("questions_filtered_out.csv", keyword_out)

print("Filtered Questions:")
for question in filtered_questions:
    print(question)

print(f"\nFiltered questions have been saved to 'filtered_questions.csv'.")
print(f"Questions filtered out have been saved to 'questions_filtered_out.csv'.")
# Out:
# Filtered Questions:
# 1,What is the reproductive event in humans?
#
# 1,What is the rationalised 202324?
#
# 1,Where is the female reproductive system located?
#
# 1,What is the name of the genital tract insemination?
#
# 1,Where is the male reproductive system located?
#
# 1,What does sperm formation continue even in old men?
#
# 1,What is the male reproductive viviparous?
#
# 1,What is the external genitalia rationalised 202324?
#
# 1,What is the female reproductive viviparous?
#
# 1,What is the male reproductive system located in?
#
# 1,What is the name of the genital tract insemination and fusion of male and female gametes fertilisation leading to formation of zygote?
#
# 1,Where is the male reproductive?
#
# 1,What is the male reproductive system?
#
# 1,What is the female reproductive system located in?
#
# 1,What does ovum cease to do in women around fifty years?
#
# 1,What is the name of the sperms in males?
#
# 1,What are the differences between the reproductive events in the male and female?
#
# 1,What is the name of the sperms in females?
#
# 1,What is the female reproductive system?
#
# 1,What is the term for transfer of sperms into the female?
#
# 1,What is the name of the text that includes a pair of testes along with accessory ducts glands?
#
# 2,How many highly coiled seminiferous tubules are in each lobule?
#
# 2,What is the vas?
#
# 2,What are the two types of cells inside each seminiferous tubul?
#
# 2,What are the regions outside of the seminiferous tubules called?
#
# 2,What are the two types of cells that line the inside of the seminiferous tubules?
#
# 2,What do sertoli cells provide?
#
# 2,What do the seminiferous tubules of the testis open into?
#
# 2,What are the regions outside the seminiferous tubules called?
#
# 2,What is the pouch that the testes are located outside the abdominal cavity within?
#
# 2,What are the leydig cells called?
#
# 2,What do male germ cells undergo?
#
# 2,What do sertoli cells provide to the germ cells?
#
# 2,What is the vasa efferentia located along the posterior surface 27 of each testis?
#
# 2,What is the urethra?
#
# 2,What is the external opening of the urethra?
#
# 2,What is the urethra called?
#
# 2,What is the length of the testis in adults?
#
# 2,What do the sertoli cells provide?
#
# 2,What are the two types of cells that line each seminiferous tubule?
#
# 2,What do leydig cells secrete?
#
# 2,What do the seminiferous tubules?
#
# 2,What are the regions outside the se?
#
# 2,What are the male sex accessory duct?
#
# 2,What do the seminiferous tubules of the testis open into through rete testis?
#
# 2,What is the epididymis located along the posterior surface 27 of each testis?
#
# 2,What do seminiferous tubules of?
#
# 2,What are interstitial spaces called?
#
# 2,What is the normal internal body temperature necessary for spermatogenesis in adults?
#
# 2,What is the normal internal body temperature needed for spermatogenesis in adults?
#
# 2,What are the male sex accessory ducts called?
#
# 2,What is the pouch called that helps in maintaining the low temperature of the testes?
#
# 2,How many compartments are in each testis?
#
# 2,How many compartments are in the testis?
#
# 2,What is the length of the testis?
#
# 2,What do leydig cells synthesise and secrete?
#
# 2,What do the seminiferous tubules of the testis?
#
# 2,What is the male reproductive system part of testis open to show inner details androgens other immunologically competent cells are also present in the male sex accessory ducts include rete testis vasa effer?
#
# 2,What does the urethra originate from?
#
# 2,What is the external opening called?
#
# 2,What is the epididymis called?
#
# 2,What is the male sex accessory duct?
#
# 2,What helps in maintaining the low temperature of the testes?
#
# 2,What is the ejaculatory duct?
#
# 2,What are the male sex accessory ducts?
#
# 2,What is the reproductive system of males?
#
# 2,What are the two types of cells that line the inside of a seminifer?
#
# 2,How many highly coiled seminiferous tubules are in the male pelvis?
#
# 2,What do leydig cells synthesise and secret?
#
# 2,What are the compartments inside the testis called?
#
# 2,What do these ducts store and transport?
#
# 2,What are the two types of cells that line the inside of a seminiferous tubule?
#
# 2,What is the width of the testis in adults?
#
# 3,What glands are included in the male accessory glands?
#
# 3,How many ovaries are located on each side of the lower abdomen?
#
# 3,What glands are secreted by the female reproductive system?
#
# 3,What is the primary female sex organs that produce the female 28 gamete ovum and several steroid hormones ovarian hormones?
#
# 3,What is the seminal plasma rich in?
#
# 3,What are the primary female sex organs that produce the female?
#
# 3,What is the secretions of bulbourethral glands also help in?
#
# 3,What is the male accessory glands called?
#
# 3,How long is each ovary?
#
# 3,What is the male external genitalia called?
#
# 3,What glands are paired seminal vesicles a prostate and paired bulbourethral glands?
#
# 3,What is the secretions of the glands that are paired seminal ves?
#
# 3,What is the enlarged end of penis called?
#
# 3,What glands help in the lubric?
#
# 3,What is the inner medulla?
#
# 3,What is the male accessory glands?
#
# 3,What is the ovarian stroma divided into?
#
# 3,What are the ovaries located on each side of?
#
# 3,What is the fold of skin on the enlarged end of penis called?
#
# 3,What is the fold of skin that covers the enlarged end of penis called?
#
# 3,What are the male accessory glands?
#
# 3,What are the primary female sex organs?
#
# 3,What is the stroma divided into?
#
# 3,What is the ovary covered by?
#
# 3,What is the female reproductive system composed of?
#
# 3,What is the length of each ovary?
#
# 3,What is the primary female sex organs that produce the female?
#
# 3,What is the inner medulla rationalised 202324?
#
# 3,What is the male external genitalia?
#
# 4,What is the length of each fallopian tube?
#
# 4,What is the female accessory ducts?
#
# 4,What is the part closer to the ovary called?
#
# 4,What is the infundibulum that leads to a wider view of the female reproductive system?
#
# 4,What do fimbriae do?
#
# 4,What year was the female reproductive system rationalised?
#
# 4,What are fimbriae?
#
# 4,What is the infundibulum called?
#
# 4,What is the name of the projections on the edges of the infundibulum called?
#
# 4,What is the name of the part closer to the ovary called?
#
# 5,What is the outer thin membranous perimetrium middle thick layer of smooth muscle myometrium and?
#
# 5,What is the name of the tiny fingerlike structure that lies at the upper junction of the two labia minora above the urethral opening?
#
# 5,What is the external thin membranous perimetrium?
#
# 5,What is the membrane that covers the opening of the vagina called?
#
# 5,What is the inner glandular?
#
# 5,What is the clitoris?
#
# 5,What is the hymen often to?
#
# 5,What is the opening of the vagina often covered partially?
#
# 5,What is the hymen called?
#
# 5,What is the hymen often torn during?
#
# 5,What is the outer thin membranous perimetrium middle thick layer of smooth muscle myometrium and inner glandular layer called called?
#
# 5,What is the hymen?
#
# 5,What is the cavity of the cervix?
#
# 5,What is the inner glandular layer called?
#
# 5,What is the cavity of the cervix called?
#
# 5,What is often torn during the first coitus intercourse?
#
# 5,What is the hymen often broken by?
#
# 5,What is the inner glandular layer called called that lines the uterine cavity?
#
# 5,What is the cushion of fatty tissue covered by?
#
# 5,What is the name of the membrane that covers the opening of the vagina?
#
# 5,What is the most reliable indicator of virginity or sexual experience?
#
# 5,What can break the hymen?
#
# 5,What is the outer thin membranous perimetrium middle thick layer of smooth muscle myometrium?
#
# 5,What is not a reliable indicator of virginity or sexual experience?
#
# 5,What is the uterus also called?
#
# 5,What is the birth canal called?
#
# 5,What is the last part of the oviduct isthmus called?
#
# 5,What are fleshy folds of tissue that extend down from the mons pubis and surround the vaginal opening?
#
# 5,What are labia majora?
#
# 5,What is the outer layer of the uterus called?
#
# 5,What is the female external genitalia called?
#
# 5,What is the shape of the uterus like?
#
# 5,What is the clitoris called?
#
# 5,What are labia minora?
#
# 6,What do the tubules of?
#
# 6,What do the alveoli open into?
#
# 6,What gland is gnrh acting at?
#
# 6,How many mammary lobes are there?
#
# 6,What is the name of the hormone that increases the seminiferous tubule?
#
# 6,What is the number of chromosomes in spermatids?
#
# 6,What do the tubules of each lobe join to form?
#
# 6,What is connected to lactiferous duct through which milk is sucked out?
#
# 6,When does spermiation begin?
#
# 6,How many chromosomes does each spermatogonium contain?
#
# 6,What is the name of the process that produces sperms?
#
# 6,What is the process called after spermiogenesis?
#
# 6,What are mammary glands?
#
# 6,What is the process called that produces sperms?
#
# 6,What is the process called that produces sperm?
#
# 6,What hormone acts at the leydig cells?
#
# 6,What hormone acts at the anterior pituitary gland?
#
# 6,What is the process called that produces spermatozoa sperms?
#
# 6,What do the cells of alveoli open into?
#
# 6,What is the process called that releases sperm heads from the seminiferous tubules?
#
# 6,What hormone is produced by the anterior pituitary gland?
#
# 6,What are the mammary glands?
#
# 6,What is the process called that produces sperms in testis?
#
# 6,What is characteristic of all female mammals?
#
# 6,What does fsh act on?
#
# 6,What hormone acts on the sertoli cells?
#
# 6,What is the name of the hormone that increases the se?
#
# 6,What do the cells of alveoli secrete?
#
# 6,How many chromosomes are in each spermatogonium?
#
# 6,What is the glandular tissue of each breast divided into?
#
# 6,What is the process called that transforms spermatids?
#
# 6,What hormone is produced by the anterior?
#
# 6,What is the process called that produces spermatozoa?
#
# 6,What cells does lh act at?
#
# 6,What is the process called that transforms spermatids into spermatozoa sperms?
#
# 6,What is the process of spermatogenesis?
#
# 6,What is the process of spermatogenesis that is stimulated by androgens?
#
# 6,What hormone is released at the anterior pituitary gland?
#
# 6,What is the name of the spermatogonium present on the inside wall of seminiferous tubules?
#
# 7,What is the rationalised 202324?
#
# 7,What is the first meiotic division of the primary oocyte?
#
# 7,What is the second meiotic division?
#
# 7,What is the process of formation of a mature female gamete called?
#
# 7,What is the sperm head composed of?
#
# 7,What are the primary follicles called?
#
# 7,What is the inner theca interna?
#
# 7,What is the first polar body?
#
# 7,What is the structure of a sperm?
#
# 7,What is the formation of a large?
#
# 7,How many sperm?
#
# 7,What is the structure of a sperm composed of?
#
# 7,What is the body of sperm covered by?
#
# 7,What are the testicular hormones androgens used for?
#
# 7,What is the secondary follicle called?
#
# 7,What is the outer theca externa?
#
# 7,What is the tertiary?
#
# 7,What are the functions of male sex accessory ducts and glands maintained by?
#
# 7,What is the sperm head covered by?
#
# 7,What are the seminal plasma along with the sperms essential for?
#
# 7,How many sperms does the human male ejaculate during a coitus?
#
# 7,What is the primary oocyte called?
#
# 7,What is the tertiary follicle arranged into?
#
# 7,What is the primary oocyte within the tertiary follicle?
#
# 7,What are the secretions of epididymis vas deferens essential for?
#
# 7,What are the primary follicles called at puberty?
#
# 7,What percentage of sperms must show?
#
# 7,What are the functions of male sex accessory?
#
# 7,What is the tertiary follicle characterized by?
#
# 7,What is the body of sperm?
#
# 7,What are the primary oocytes called?
#
# 7,What is the process of formation of a mature female gamete markedly different from?
#
# 7,What is the result of the unequal division?
#
# 7,What is the primary follicle called?
#
# 7,How many sperms must have normal shape and size for normal fertility?
#
# 7,How many sperms does a?
#
# 7,How many sperms does a human male ejaculate during a coitus?
#
# 7,When is oogenesis initiated?
#
# 7,What is the tertiary follicle characterised by?
#
# 7,What is the first stage of oogenesis?
#
# 7,What is the acrosome filled with?
#
# 7,What is the process of formation of?
#
# 8,What is the process called that releases the secondary oocyte ovum from the ovary?
#
# 8,What is the name of the membrane that surrounds the secondary oocyte called?
#
# 8,What is the first menstruation called in human females?
#
# 8,How many days is the average interval of menstruation?
#
# 8,What is the reproductive cycle in the female primates?
#
# 8,What is the diagrammatic representation of?
#
# 8,What is the reproductive cycle in humans called?
#
# 8,What is the reproductive cycle in female primates called?
#
# 8,When is ovum released ovulation?
#
# 8,What is the reproductive cycle in primates?
#
# 8,What is the first menstruation called in humans?
#
# 8,What is the average interval of menstruation in human females?
#
# 8,What is the first menstruation called in monkeys apes and human beings?
#
# 8,What is the membrane that surrounds the secondary oocyte called?
#
# 8,What is the term for the membrane that surrounds the secondary oocyte called?
#
# 8,What is the process called that releases the secondary o?
#
# 8,What is the reproductive cycle in the female primates e g monkeys apes and humans called?
#
# 8,What is the reproductive cycle in the female primates called?
#
# 8,What is the reproductive cycle in human females called?
#
# 8,What is the process called that releases the secondary oocyte ovum from the?
#
# 8,What is the name of the membrane that the secondary oocyte forms around it?
#
# 8,What is the reproductive cycle in humans?
#
# 8,What is the term for the mature follicle?
#
# 8,When does the first menstruation begin in human females?
#
# 8,What is the cycle of events starting from one menstruation till the next one called?
#
# 9,What phase is followed by the menstrual phase?
#
# 9,What is the main event of the menstrual cycle?
#
# 9,What is the breakdown of the endometrial lining of the uterus and its blood vessels that forms liquid that comes out through vagina?
#
# 9,What is the secretion of rationalised 202324?
#
# 9,What is the menstrual?
#
# 9,What is the cause of the breakdown of the endometrial lining of the uterus and its blood vessels?
#
# 9,What is the first phase of the menstrual cycle?
#
# 9,What is the only time menstruation occurs?
#
# 9,What phase is followed by the follicular phase?
#
# 9,What is the duration of the menstrual cycle?
#
# 9,What is the duration of the cycle?
#
# 9,What is the menstrual phase followed by?
#
# 9,What does the endometrium of uterus regenerate through?
#
# 9,What is the result of the breakdown of the endometrial lining of the uterus and its blood vessels?
#
# 9,What hormones are induced by changes in the ovary and?
#
# 9,What is the menstrual phase?
#
# 9,What is the first phase of the cycle?
#
# 9,What is the endometrium of uterus regenerating through?
#
# 9,What hormones are induced by changes in the ova?
#
# 9,What hormones are involved in the ovulation and uterus?
#
# 9,What is the menstrual flow?
#
# 9,What is the follicular phase?
#
# 9,What do the primary follicles in the ovary grow to become?
#
# 9,What is the menstrual flow caused by?
#
# 10,What is the zona pellucida?
#
# 10,What is the luteal phase?
#
# 10,What is the process of fusion of a sperm with an ovum called?
#
# 10,What is the corpus homemade pads called?
#
# 10,What does fertilisation do to the?
#
# 10,What is the term used for the menstrual cycles that ceases around 50 years of age?
#
# 10,What is the term for the absence of sanitary napkins of fertilisation?
#
# 10,What causes disintegration properly wrapping it with a used paper do of the endometrium leading to menstruation marking a new cycle in not?
#
# 10,What is the term for the menopause?
#
# 10,What is the process of fusion of a?
#
# 10,What is the corpus luteum secreted?
#
# 10,What is the corpus?
#
# 10,What is the corpus luteum secreted large amounts of?
#
# 10,What hormone is secrete?
#
# 10,What is the acrosome secretions that help the sperm enter into the cytoplasm of the ovum through the zona pellucida and the plasma figure 2 10 ovum surrounded by few?
#
# 10,What secretions help the sperm enter into the cytoplasm of the ovum?
#
# 10,What is the plasma figure 2 10 ovum surrounded by few?
#
# 10,What is the peak level of lh and fsh?
#
# 10,What is the luteal phase followed by?
#
# 10,What hormones are secreted by the growing follicles during the luteal phase?
#
# 10,What is the term for the cycle that ends around 50 years of age?
#
# 10,What is the term for the menstrual cycle that ends around 50 years of age?
#
# 10,What is released by the penis into the vagina?
#
# 10,What is the process of fusion of a sper?
#
# 10,What is the corpus luteum essential for maintenance of?
#
# 10,What is the release of ovum ovulation?
#
# 10,What is the maximum level of lh during the midcycle called?
#
# 10,What does the acrosome help the sperm enter into the cytoplasm of the ovum through the zona pellucida and the plasma?
#
# 10,What is essential for maintenance of the endometrium napkins or homemade?
#
# 10,What is the ovum surrounded by few?
#
# 10,What does fertilisation do to the ovum?
#
# 10,What causes disintegration properly wrapping it with a used paper do of the endometrium leading to menstruation?
#
# 10,What does the sperm induce that blocks the entry of additional sperms?
#
# 10,What layer of the ovum is in contact with during fertilisation?
#
# 10,What hormone is secreted by the corpus luteum during the luteal phase?
#
# 10,What is the secreted change sanitary progesterone essential for maintenance of?
#
# 10,What is the maximum level during the midcycle called?
#
# 10,What is necessary for implantation of fertilised pads after every 45 hrs as per the requirement ovum and other events of pregnancy during pregnancy?
#
# 10,What is an indicator of normal drainpipe of toilets or reproductive phase?
#
# 10,What is the corpus luteum secreted for?
#
# 10,What is necessary for implantation of fertilised pads after every 45 hrs as?
#
# 10,What is fertilisation?
#
# 10,How many sperms can fertilise an o?
#
# 10,What is the term used for the menopause?
#
# 10,What is the ampullary region where fertilisation takes place?
#
# 10,What is the luteal phase of the graafian follicle?
#
# 11,What is the second meiotic division?
#
# 11,What would a zygote carrying xx develop into?
#
# 11,What is the sex of the baby determined?
#
# 11,What would a zygote carrying xy form a male baby?
#
# 11,What would the zygote carry xy form?
#
# 11,What would the zygote carry xx develop into?
#
# 11,What is the mitotic division started as the zygote moves through the isthmus of the ovi?
#
# 11,What is the number of embryos in the embryo?
#
# 11,What is the chromosome pattern in the male?
#
# 11,What is the chromosome pattern in the human female?
#
# 11,What would the zygote carry after fusion of the male and female gametes?
#
# 11,What percentage of sperms carry the x chromosome?
#
# 11,What is the sex of the baby determined by?
#
# 11,What cells are called blastomeres the embryo with 8 to 16 36 figure 2 11 transport of ovum fertilisation and passage of growing embryo through fallopian tube rationalised 202324?
#
# 11,What percentage of sperms carry the y chromosome?
#
# 12,What is the placenta?
#
# 12,What hormone is secreted by the ovary?
#
# 12,What is the human reproduction blastomeres called?
#
# 12,What is the name of the trophoblast that is surrounded by the uterine tissue and maternal blood?
#
# 12,What is the name of the text that differentiates the embryo after implantation?
#
# 12,What is the term for the trophoblast that is surrounded?
#
# 12,What is the process of implantation called?
#
# 12,What is the placenta connected to?
#
# 12,What hormone is secreted by the ovary during pregnancy?
#
# 12,What hormone is secreted by the ovary in the later phase of pregnancy?
#
# 12,What is the name of the hormone secreted by?
#
# 12,What is the name of the text that is based on the human foetus within the uterus rationalised 202324?
#
# 12,What is the main reason for increased production of these hormones?
#
# 12,What is the term for the trophoblast that is surrounded by the uterine tissue and maternal blood?
#
# 12,What is the outer layer of the blast?
#
# 12,What is the inner cell mass called?
#
# 12,What is the outer layer of the blastomeres called?
#
# 12,What hormones are produced in women only during pregnancy?
#
# 12,What is the name of the trophoblast that is surrounded by uterine tissue and maternal blood?
#
# 12,What is the name of the hormone secreted by the ovary during pregnancy?
#
# 12,What is the name of the text that is based on the human foetus within?
#
# 12,What is the outer layer of the blastomeres in the blastocyst called?
#
# 12,What is the outer layer of human reproduction blastomeres called?
#
# 12,What is the process that leads to pregnancy?
#
# 12,What is the inner cell mass attached to the outer layer of the blastomeres?
#
# 12,What is the placenta endocrine tissue?
#
# 12,What is the 11 step h that leads to pregnancy?
#
# 13,How long does human pregnancy last in dogs elephants cats find out in humans after one month of pregnancy?
#
# 13,What do the three layers give rise to in adults?
#
# 13,What is the first sign of growing foetus in human beings?
#
# 13,What causes stronger uterine contractions?
#
# 13,What is the first time a baby is breast?
#
# 13,What is the average duration of human pregnancy called?
#
# 13,What is the process of delivery of the foetus called?
#
# 13,What does oxytocin do to the uterine muscle?
#
# 13,What is the main feature of embryonic development at various months of pregnancy?
#
# 13,What is the process called during pregnancy called?
#
# 13,How long does human pregnancy last?
#
# 13,What is the inner cell mass called?
#
# 13,What is the inner cell mass of the embryo called?
#
# 13,What are the three layers that give rise?
#
# 13,What is the first sign of growing foetus?
#
# 13,What is parturition induced by?
#
# 13,How long does a human pregnancy last?
#
# 13,What is the outer layer called?
#
# 13,What is the process called during lactation?
#
# 13,What is the process called that helps the mother in feeding the new born?
#
# 13,How long does the human pregnancy last?
#
# 13,What is the average duration of human pregnancy?
#
# 13,What triggers release of oxytocin from the maternal pituit?
#
# 13,What are the cells called in the inner cell mass?
#
# 13,What is the first sign of growing foetus noticed by listening to the heart sound carefully through the stethoscope?
#
# 13,How long does human pregnancy last in dogs elephants cats find out in humans?
#
# 13,What is parturition?
#
# 13,What is the first time a baby is breastfed?
#
# 13,By the end of the second month of pregnancy the foetus develops limbs and digits by the end of 12 weeks first trimester most of the major organ systems are formed by the end of 12 weeks first trim?
#
# 13,What is the process called during pregnancy that helps the mother in feeding the new born?
#
# 13,What is the inner layer called?
#
# 13,What triggers release of oxytocin from the maternal?
#
# 13,What is the first sign of growing foetus noticed by listening?
#
# 13,How long does pregnancy last in dogs elephants cats?
#
# 13,How long does the human pregnancy last in dogs elephants cats?
#
# 13,What is the milk produced during the initial few days of lactation called?
#
# 13,What triggers release of oxytocin from the maternal pituitary?
#
# 14,What are the ovarian hormones embedded in?
#
# 14,What is the female gamete ovum produced by?
#
# 14,What is one of the female external genitalia?
#
# 14,What is the process of childbirth called?
#
# 14,How many highly coiled seminiferous tubules are in each testis?
#
# 14,What do sertoli cells provide to the germ cells?
#
# 14,How many compartments does each testis have?
#
# 14,What is the reproductive cycle of female primates called?
#
# 14,What is the male external genitalia called?
#
# 14,What are the oviducts?
#
# 14,What is the process of formation of mature female gametes called?
#
# 14,What is the process of formation of mature female gametes?
#
# 14,What are the oviducts uterus and vagina?
#
# 14,What are the three layers of the?
#
# 14,What is the newborn baby fed by the mother?
#
# 14,What are the ovaries producing?
#
# 14,What is the female external genitalia?
#
# 14,What is the process of childbirth?
#
# 14,What is parturition induced by?
#
# 14,What do leydig cells outside the seminiferous tubules synthesise and secrete?
#
# 14,What is one of the female secondary sexual characteristics?
#
# 14,What is fertilisation in humans externalinternal?
#
# 14,What is the first stage of menstrual cycle?
#
# 14,What hormones are involved in ovulation?
#
# 14,What is the uterus's third layer?
#
# 14,How many compartments are in each testis?
#
# 14,What is the male reproductive system composed of?
#
# 14,What do sertoli cells provide to the dividing germ cells?
#
# 14,What glands differentiate during pregnancy and secrete milk after childbirth?
#
# 14,What do spermatogonia undergo?
#
# 14,What is fed by the mother after childbirth?
#
# 14,What is parturition?
#
# 14,What do mammary glands differentiate during pregnancy and secrete after childbirth?
#
# 14,What is the normal human sperm composed of?
#
# 14,What are the ovarian follicles embedded in?
#
# 14,What is the zygote is rationalised 20?
#
# 14,What hormones are involved in the cyclical changes in the ovary and uterus during menstrual cycle?
#
# 14,What are the testicular lobules called?
#
# 14,What are testicular hormones called?
#
# 14,What is the female reproductive system composed of?
#
# 14,What hormones are involved in the cyclical changes in?
#
# 14,What determines the sex of the embryo?
#
# 14,What is the name of the process of childbirth?
#
# 15,What is the fusion of male and female gametes called?
#
# 15,What are spermatozoa get nutrition from?
#
# 15,What are the hormones involved in regulation of spermatogenesis?
#
# 15,What are the major functions of male accessory ducts and glands?
#
# 15,What type of cell is?
#
# 15,What type of cell is found in ovary?
#
# 15,What do truefalse b spermatozoa get nutrition from?
#
# 15,What is a graafian follicle?
#
# 15,What is the name of the graafian?
#
# 15,What hormones regulate menstrual cycle?
#
# 15,How many eggs are released by a human ova?
#
# 15,How many eggs do you think would have been released if the mother gave birth to identical twins would your answer change if the twins born were?
#
# 15,What are androgens produced by?
#
# 15,What is the name of the graafian follicle?
#
# 15,What cells produce and?
#
# 15,Where are truefalse c leydig cells found?
#
# 15,Name the hormones involved in regulation of spermatogenesis?
#
# 15,What are the two major functions of testis and ovary?
#
# 15,What hormone induces ovulation?
#
# 15,What is the structure which provides vascular connection between foetus and uterus called?
#
# 15,What type of cells produce androgens?
#
# 15,How many eggs are released by a human ovary in a month?
#
# 15,What is the structure of a seminiferous tubule?
#
# 15,What type of cells are found in ovary?
#
# 15,What is not a reliable indicator of virginity or sexual experience truefalse g presence or absence of hymen is not a reliable indicator of virginity or sexual experience truefalse?
#
# 15,What is spermatogenesis?
#
# 15,What is spermatogenesis briefly describe the process of spermatogenesis?
#
# 15,Where does oogenesis take place?
#
# 15,What is not a reliable indicator of virginity or sexual experience?
#
# 15,What is spermiation?
#
# 15,What happens during pregnancy?
#
# 15,What cells are found in ovary?
#
# 15,How many eggs are released by a human ovary in?
#
# 15,What cells produce androgens?
#
# 15,Where do truefalse e oogenesis take place?
#
# 15,What is parturition?
#
# 15,What is spermatogenesis briefly describe the process?
#
# 15,What are the major components of seminal plasma?
#
# 15,What is spermiogenesis?
#
# 15,What is oogenesis?
#
# 15,Name the functions of the following a corpus luteum b endo?
#
# 15,What hormones are involved in induction of parturition?
#
# 15,What is the process of release of ovum from a mature follicle called?
#
# 15,Where do truefalse d leydig cells synthesise androgens?
#
# 15,What is not a reliable indicator of virginity or sexual experience truefalse g presence or absence of hymen is not a reliable indicator of virginity or sexual experience truefalse g presence or absence of?
#
# 15,What is oogenesis give a brief account of oogenesis?
#
#
# Filtered questions have been saved to 'filtered_questions.csv'.
# Questions filtered out have been saved to 'questions_filtered_out.csv'.

# %%
import pandas as pd
pd.read_csv('filtered_questions.csv')
# Out:
#                                               Question
# 0        1,What is the reproductive event in humans?\n
# 1                 1,What is the rationalised 202324?\n
# 2    1,Where is the female reproductive system loca...
# 3    1,What is the name of the genital tract insemi...
# 4    1,Where is the male reproductive system locate...
# ..                                                 ...
# 485  15,What hormones are involved in induction of ...
# 486  15,What is the process of release of ovum from...
# 487  15,Where do truefalse d leydig cells synthesis...
# 488  15,What is not a reliable indicator of virgini...
# 489  15,What is oogenesis give a brief account of o...
#
# [490 rows x 1 columns]

# %%
keyword_out
# Out:
# ['Page,Generated Questions\n',
#  '1,?\n',
#  '1,What is the name?\n',
#  '1,What?\n',
#  '2,What are the two types?\n',
#  '2,?\n',
#  '2,What are?\n',
#  '2,What?\n',
#  '2,What is?\n',
#  '2,How many compartments are in?\n',
#  '2,How many highly coiled seminifer?\n',
#  '3,What is the secretions of the bulboureth?\n',
#  '3,?\n',
#  '3,What is the length of each?\n',
#  '3,What is the length of?\n',
#  '3,What is the secretions of?\n',
#  '3,What?\n',
#  '3,What is?\n',
#  '4,?\n',
#  '4,What is the?\n',
#  '4,What?\n',
#  '5,?\n',
#  '5,What is the outer thin membranous peri?\n',
#  '5,What?\n',
#  '5,What is the question for the following text?\n',
#  '5,What is the?\n',
#  '5,What can also be broken by a sudden fall or jolt?\n',
#  '6,What are mamm?\n',
#  '6,?\n',
#  '6,What is the name?\n',
#  '6,What is the process called that?\n',
#  '6,What?\n',
#  '6,What is the?\n',
#  '6,What is the process of sper?\n',
#  '7,?\n',
#  '7,How many sper?\n',
#  '7,What are the?\n',
#  '7,What is the?\n',
#  '7,What is the structure of a sper?\n',
#  '7,How many?\n',
#  '8,?\n',
#  '8,What is the name of the process that?\n',
#  '8,How many days is the average interval of menstru?\n',
#  '8,What?\n',
#  '8,When is?\n',
#  '9,?\n',
#  '9,What is the result?\n',
#  '10,?\n',
#  '10,What is the term for the meno?\n',
#  '10,What is the term?\n',
#  '10,What?\n',
#  '10,What is released by the pen?\n',
#  '10,What is the process of?\n',
#  '11,?\n',
#  '11,What?\n',
#  '11,What is?\n',
#  '11,What percentage of sper?\n',
#  '12,?\n',
#  '12,What?\n',
#  '12,What is the 11 step h that leads to?\n',
#  '12,What is the?\n',
#  '12,What is the main reason for increased?\n',
#  '12,What is the placen?\n',
#  '13,What triggers release of oxytoc?\n',
#  '13,?\n',
#  '13,What?\n',
#  '13,What is the process called that helps?\n',
#  '13,What is the gestation period?\n',
#  '13,What triggers release?\n',
#  '14,""" What is the name of the text that is based on the question ""What is?"\n',
#  '14,What is the name of the exercise that answers the question?\n',
#  '14,?\n',
#  '14,What are the?\n',
#  '14,What is the name of the exercise that answers the?\n',
#  '14,What is fertil?\n',
#  '14,What are the three?\n',
#  '14,What?\n',
#  '14,What is?\n',
#  '14,"What is the name of the text that is based on the question ""What is the name of the text that is based on the question ""?"\n',
#  '15,What are the functions of the following?\n',
#  '15,How?\n',
#  '15,?\n',
#  '15,What is oo?\n',
#  '15,What is the name of the function of the following?\n',
#  '15,Where does?\n',
#  '15,What?\n',
#  '15,How many eggs?\n',
#  '15,What is often blamed for giving birth to daughters?\n',
#  '15,What is the?\n',
#  '15,Name the functions?\n',
#  '15,What is the structure which provides?\n',
#  '15,How many eggs do you think would have been released if the?\n']

# %% [markdown]
# # Grammar Checking

# %%
import torch
import csv
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("grammarly/coedit-large")
model = AutoModelForSeq2SeqLM.from_pretrained("grammarly/coedit-large")

def correct_questions(questions):
    corrected_questions = []

    for question in questions:
        input_ids = tokenizer.encode(question, return_tensors="pt")
        with torch.no_grad():
            corrected_output = model.generate(input_ids)
        corrected_question = tokenizer.decode(corrected_output[0], skip_special_tokens=True)

        corrected_questions.append(corrected_question)

    return corrected_questions


corrected_questions = correct_questions(filtered_questions)

csv_file_path = "corrected_questions.csv"

with open(csv_file_path, mode='w', newline='') as file:
    writer = csv.writer(file)
    
    writer.writerow(['Original Question', 'Corrected Question'])

    for original, corrected in zip(filtered_questions, corrected_questions):
        writer.writerow([original, corrected])

print(f"Results saved to {csv_file_path}")
# Out:
# c:\Users\sriyo\AppData\Local\Programs\Python\Python310\lib\site-packages\transformers\generation\utils.py:1254: UserWarning: Using the model-agnostic default `max_length` (=20) to control thegeneration length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Results saved to corrected_questions.csv

# %%
def save_questions_to_file(questions, file_path):
    with open(file_path, 'w', encoding='utf-8') as file:
        for question in questions:
            file.write(question + '\n')

output_file_path = 'grammar_corrected.txt'

save_questions_to_file(, output_file_path)

# %%
pd.read_csv('corrected_questions.csv')
# Out:
#                                      Original Question  \
# 0        1,What is the reproductive event in humans?\n
# 1                 1,What is the rationalised 202324?\n
# 2    1,Where is the female reproductive system loca...
# 3    1,What is the name of the genital tract insemi...
# 4    1,Where is the male reproductive system locate...
# ..                                                 ...
# 485  15,What hormones are involved in induction of ...
# 486  15,What is the process of release of ovum from...
# 487  15,Where do truefalse d leydig cells synthesis...
# 488  15,What is not a reliable indicator of virgini...
# 489  15,What is oogenesis give a brief account of o...
#
#                                     Corrected Question
# 0         1, What is the reproductive event in humans?
# 1                   1,What is the rationalized 202324?
# 2    1, Where is the female reproductive system loc...
# 3    1,What is the name of the genital tract insemi...
# 4     1,Where is the male reproductive system located?
# ..                                                 ...
# 485  15,What hormones are involved in the formation...
# 486  15 What is the process of release of ovum from...
# 487  15,Where do truefalse d leydig cells synthesiz...
# 488  15,What is not a reliable indicator of virgini...
# 489  15,What is oogenesis give a brief account of o...
#
# [490 rows x 2 columns]

# %%
def save_questions_to_file(questions, file_path):
    with open(file_path, 'w', encoding='utf-8') as file:
        for question in questions:
            file.write(question + '\n')

output_file_path = 'keyword_filtered.txt'

save_questions_to_file(keyword_out, output_file_path)

# %%
filtered_questions
# Out:
# ['What is the male reproductive system located in?',
#  'What is the name of the text that includes a pair of testes along with accessory ducts glands?',
#  'Where is the female reproductive system located?',
#  'What is the female reproductive system located in?',
#  'What is the male reproductive viviparous?',
#  'What is the name of the sperms in males?',
#  'What is the female reproductive system?',
#  'What is the name of the sperms in females?',
#  'Where is the male reproductive?',
#  'What is the name of the genital tract insemination?',
#  'Where is the male reproductive system located?',
#  'What is the term for transfer of sperms into the female?',
#  'What is the male reproductive system?',
#  'What is the female reproductive viviparous?',
#  'What does ovum cease to do in women around fifty years?',
#  'What is the reproductive event in humans?',
#  'What are the differences between the reproductive events in the male and female?',
#  'What is the external opening called?',
#  'What is the male sex accessory duct?',
#  'What is the pouch that the testes are located outside the abdominal cavity within?',
#  'What is the normal internal body temperature necessary for spermatogenesis in adults?',
#  'What is the urethra called?',
#  'What are the male sex accessory duct?',
#  'What is the length of the testis in adults?',
#  'What is the epididymis called?',
#  'What is the reproductive system of males?',
#  'What are interstitial spaces called?',
#  'What does the urethra originate from?',
#  'What are the male sex accessory ducts called?',
#  'What is the epididymis located along the posterior surface 27 of each testis?',
#  'What is the external opening of the urethra?',
#  'What is the pouch called that helps in maintaining the low temperature of the testes?',
#  'What helps in maintaining the low temperature of the testes?',
#  'What are the compartments inside the testis called?',
#  'What do these ducts store and transport?',
#  'What is the normal internal body temperature needed for spermatogenesis in adults?',
#  'What do male germ cells undergo?',
#  'What are the male sex accessory ducts?',
#  'What is the length of the testis?',
#  'What is the male accessory glands called?',
#  'What is the enlarged end of penis called?',
#  'What is the primary female sex organs that produce the female?',
#  'What is the inner medulla?',
#  'How long is each ovary?',
#  'What is the male accessory glands?',
#  'What are the primary female sex organs that produce the female?',
#  'What is the length of each?',
#  'What is the seminal plasma rich in?',
#  'What is the male external genitalia?',
#  'What is the length of each ovary?',
#  'What is the secretions of?',
#  'What is the female reproductive system composed of?',
#  'What are the male accessory glands?',
#  'What is the fold of skin that covers the enlarged end of penis called?',
#  'What is the male external genitalia called?',
#  'What glands are included in the male accessory glands?',
#  'What are the primary female sex organs?',
#  'What is the fold of skin on the enlarged end of penis called?',
#  'What is the length of?',
#  'What glands are secreted by the female reproductive system?',
#  'What is the infundibulum that leads to a wider view of the female reproductive system?',
#  'What is the length of each fallopian tube?',
#  'What is the infundibulum called?',
#  'What is the name of the part closer to the ovary called?',
#  'What is the female accessory ducts?',
#  'What is the name of the projections on the edges of the infundibulum called?',
#  'What is the part closer to the ovary called?',
#  'What is the clitoris called?',
#  'What is the inner glandular?',
#  'What is the birth canal called?',
#  'What is the outer layer of the uterus called?',
#  'What is the inner glandular layer called?',
#  'What is the uterus also called?',
#  'What is the opening of the vagina often covered partially?',
#  'What is the hymen often torn during?',
#  'What is often torn during the first coitus intercourse?',
#  'What is the membrane that covers the opening of the vagina called?',
#  'What is the last part of the oviduct isthmus called?',
#  'What is the hymen called?',
#  'What is not a reliable indicator of virginity or sexual experience?',
#  'What is the most reliable indicator of virginity or sexual experience?',
#  'What is the cavity of the cervix called?',
#  'What is the name of the membrane that covers the opening of the vagina?',
#  'What is the female external genitalia called?',
#  'What is the question for the following text?',
#  'What is the shape of the uterus like?',
#  'What are the mammary glands?',
#  'What is connected to lactiferous duct through which milk is sucked out?',
#  'What is the name of the process that produces sperms?',
#  'What do the tubules of?',
#  'What do the cells of alveoli secrete?',
#  'What hormone acts at the anterior pituitary gland?',
#  'What is the process called that produces sperm?',
#  'What is the process called that?',
#  'What do the cells of alveoli open into?',
#  'What hormone is produced by the anterior pituitary gland?',
#  'What is the process of spermatogenesis that is stimulated by androgens?',
#  'What is characteristic of all female mammals?',
#  'What is the process called that produces sperms?',
#  'What is the process called that produces sperms in testis?',
#  'What is the process called that transforms spermatids?',
#  'What is the process called that transforms spermatids into spermatozoa sperms?',
#  'What is the glandular tissue of each breast divided into?',
#  'What is the process called that produces spermatozoa sperms?',
#  'What do the tubules of each lobe join to form?',
#  'What hormone is released at the anterior pituitary gland?',
#  'What is the process called that produces spermatozoa?',
#  'What is the process of spermatogenesis?',
#  'What is the number of chromosomes in spermatids?',
#  'What are mammary glands?',
#  'What is the second meiotic division?',
#  'What are the primary follicles called?',
#  'What is the primary oocyte called?',
#  'What are the functions of male sex accessory ducts and glands maintained by?',
#  'What is the first meiotic division of the primary oocyte?',
#  'What percentage of sperms must show?',
#  'When is oogenesis initiated?',
#  'How many sperms must have normal shape and size for normal fertility?',
#  'What is the body of sperm covered by?',
#  'What is the result of the unequal division?',
#  'What is the primary oocyte within the tertiary follicle?',
#  'What are the secretions of epididymis vas deferens essential for?',
#  'What are the functions of male sex accessory?',
#  'What are the testicular hormones androgens used for?',
#  'What is the secondary follicle called?',
#  'What is the first stage of oogenesis?',
#  'What is the primary follicle called?',
#  'What is the formation of a large?',
#  'What are the primary oocytes called?',
#  'What are the primary follicles called at puberty?',
#  'What is the first polar body?',
#  'How many sperms does the human male ejaculate during a coitus?',
#  'What is the body of sperm?',
#  'What is the structure of a sperm?',
#  'What are the seminal plasma along with the sperms essential for?',
#  'What is the process of formation of a mature female gamete markedly different from?',
#  'What is the structure of a sperm composed of?',
#  'How many sperms does a human male ejaculate during a coitus?',
#  'What is the tertiary follicle arranged into?',
#  'What is the process of formation of a mature female gamete called?',
#  'What is the process called that releases the secondary o?',
#  'What is the reproductive cycle in female primates called?',
#  'What is the diagrammatic representation of?',
#  'What is the cycle of events starting from one menstruation till the next one called?',
#  'What is the name of the membrane that the secondary oocyte forms around it?',
#  'What is the reproductive cycle in the female primates?',
#  'What is the name of the membrane that surrounds the secondary oocyte called?',
#  'What is the reproductive cycle in primates?',
#  'What is the reproductive cycle in the female primates e g monkeys apes and humans called?',
#  'What is the average interval of menstruation in human females?',
#  'When is ovum released ovulation?',
#  'When does the first menstruation begin in human females?',
#  'What is the process called that releases the secondary oocyte ovum from the ovary?',
#  'What is the membrane that surrounds the secondary oocyte called?',
#  'What is the term for the membrane that surrounds the secondary oocyte called?',
#  'What is the reproductive cycle in human females called?',
#  'What is the first menstruation called in humans?',
#  'How many days is the average interval of menstruation?',
#  'What is the reproductive cycle in humans?',
#  'What is the reproductive cycle in the female primates called?',
#  'What is the reproductive cycle in humans called?',
#  'What is the first menstruation called in monkeys apes and human beings?',
#  'What is the first menstruation called in human females?',
#  'What do the primary follicles in the ovary grow to become?',
#  'What is the follicular phase?',
#  'What is the duration of the menstrual cycle?',
#  'What is the endometrium of uterus regenerating through?',
#  'What hormones are induced by changes in the ova?',
#  'What is the menstrual flow caused by?',
#  'What is the cause of the breakdown of the endometrial lining of the uterus and its blood vessels?',
#  'What does the endometrium of uterus regenerate through?',
#  'What is the first phase of the cycle?',
#  'What is the main event of the menstrual cycle?',
#  'What hormones are induced by changes in the ovary and?',
#  'What is the duration of the cycle?',
#  'What is the menstrual phase followed by?',
#  'What is the menstrual?',
#  'What phase is followed by the menstrual phase?',
#  'What is the first phase of the menstrual cycle?',
#  'What hormones are involved in the ovulation and uterus?',
#  'What is the menstrual flow?',
#  'What phase is followed by the follicular phase?',
#  'What is the menstrual phase?',
#  'What is the breakdown of the endometrial lining of the uterus and its blood vessels that forms liquid that comes out through vagina?',
#  'What is the result of the breakdown of the endometrial lining of the uterus and its blood vessels?',
#  'What is the process of fusion of a sperm with an ovum called?',
#  'What hormones are secreted by the growing follicles during the luteal phase?',
#  'What is the corpus luteum secreted large amounts of?',
#  'What is essential for maintenance of the endometrium napkins or homemade?',
#  'What is the term used for the menstrual cycles that ceases around 50 years of age?',
#  'What is the luteal phase?',
#  'What does the sperm induce that blocks the entry of additional sperms?',
#  'What is the secreted change sanitary progesterone essential for maintenance of?',
#  'What is the term for the cycle that ends around 50 years of age?',
#  'What is released by the penis into the vagina?',
#  'What is the corpus homemade pads called?',
#  'What causes disintegration properly wrapping it with a used paper do of the endometrium leading to menstruation marking a new cycle in not?',
#  'What is an indicator of normal drainpipe of toilets or reproductive phase?',
#  'What is the luteal phase followed by?',
#  'What causes disintegration properly wrapping it with a used paper do of the endometrium leading to menstruation?',
#  'What hormone is secreted by the corpus luteum during the luteal phase?',
#  'What is the ovum surrounded by few?',
#  'What is the release of ovum ovulation?',
#  'What secretions help the sperm enter into the cytoplasm of the ovum?',
#  'What is the term for the menstrual cycle that ends around 50 years of age?',
#  'What is released by the pen?',
#  'What would the zygote carry xx develop into?',
#  'What is the second meiotic division?',
#  'What would the zygote carry after fusion of the male and female gametes?',
#  'What is the chromosome pattern in the human female?',
#  'What percentage of sperms carry the x chromosome?',
#  'What is the sex of the baby determined by?',
#  'What is the sex of the baby determined?',
#  'What is the chromosome pattern in the male?',
#  'What would a zygote carrying xx develop into?',
#  'What percentage of sperms carry the y chromosome?',
#  'What is the number of embryos in the embryo?',
#  'What is the process of implantation called?',
#  'What is the 11 step h that leads to pregnancy?',
#  'What is the name of the hormone secreted by the ovary during pregnancy?',
#  'What is the outer layer of the blast?',
#  'What is the main reason for increased production of these hormones?',
#  'What hormone is secreted by the ovary in the later phase of pregnancy?',
#  'What hormones are produced in women only during pregnancy?',
#  'What is the name of the text that differentiates the embryo after implantation?',
#  'What is the process that leads to pregnancy?',
#  'What is the inner cell mass called?',
#  'What is the placenta endocrine tissue?',
#  'What hormone is secreted by the ovary during pregnancy?',
#  'What is the placenta?',
#  'What is the placenta connected to?',
#  'How long does pregnancy last in dogs elephants cats?',
#  'What is parturition?',
#  'How long does human pregnancy last?',
#  'What is the inner layer called?',
#  'How long does the human pregnancy last?',
#  'What does oxytocin do to the uterine muscle?',
#  'How long does human pregnancy last in dogs elephants cats find out in humans after one month of pregnancy?',
#  'What triggers release of oxytocin from the maternal pituitary?',
#  'What is the outer layer called?',
#  'What is the process called during pregnancy called?',
#  'What is the milk produced during the initial few days of lactation called?',
#  'What is the inner cell mass of the embryo called?',
#  'How long does a human pregnancy last?',
#  'What triggers release?',
#  'How long does human pregnancy last in dogs elephants cats find out in humans?',
#  'What is parturition induced by?',
#  'What triggers release of oxytocin from the maternal?',
#  'What is the process called that helps?',
#  'What is the average duration of human pregnancy called?',
#  'What causes stronger uterine contractions?',
#  'What are the three layers that give rise?',
#  'What do the three layers give rise to in adults?',
#  'What is the inner cell mass called?',
#  'What is the process called during lactation?',
#  'What is the gestation period?',
#  'How long does the human pregnancy last in dogs elephants cats?',
#  'What are the cells called in the inner cell mass?',
#  'What is the main feature of embryonic development at various months of pregnancy?',
#  'What is the average duration of human pregnancy?',
#  'What is the process of formation of mature female gametes called?',
#  'What is the female external genitalia?',
#  'What is parturition?',
#  'What are the ovarian hormones embedded in?',
#  'What is the name of the process of childbirth?',
#  'What is the process of childbirth?',
#  'What are testicular hormones called?',
#  'What is one of the female external genitalia?',
#  'What hormones are involved in the cyclical changes in?',
#  'What do mammary glands differentiate during pregnancy and secrete after childbirth?',
#  'What are the oviducts?',
#  'What is the process of formation of mature female gametes?',
#  'What is fed by the mother after childbirth?',
#  'What is the female gamete ovum produced by?',
#  'What hormones are involved in the cyclical changes in the ovary and uterus during menstrual cycle?',
#  'What are the oviducts uterus and vagina?',
#  'What are the ovaries producing?',
#  'What is the normal human sperm composed of?',
#  'What is parturition induced by?',
#  'What do spermatogonia undergo?',
#  'What is the female reproductive system composed of?',
#  'What glands differentiate during pregnancy and secrete milk after childbirth?',
#  'What are the ovarian follicles embedded in?',
#  'What is the process of childbirth called?',
#  'What is the first stage of menstrual cycle?',
#  'What is the male external genitalia called?',
#  'What determines the sex of the embryo?',
#  "What is the uterus's third layer?",
#  'What is the male reproductive system composed of?',
#  'What is the reproductive cycle of female primates called?',
#  'What hormones are involved in ovulation?',
#  'What is one of the female secondary sexual characteristics?',
#  'What cells are found in ovary?',
#  'What is often blamed for giving birth to daughters?',
#  'What are the major functions of male accessory ducts and glands?',
#  'What is parturition?',
#  'How many eggs are released by a human ovary in a month?',
#  'How many eggs are released by a human ovary in?',
#  'What are the functions of the following?',
#  'What cells produce androgens?',
#  'Name the hormones involved in regulation of spermatogenesis?',
#  'What are the major components of seminal plasma?',
#  'How many eggs do you think would have been released if the mother gave birth to identical twins would your answer change if the twins born were?',
#  'What is oogenesis give a brief account of oogenesis?',
#  'What is the process of release of ovum from a mature follicle called?',
#  'What are androgens produced by?',
#  'What is spermatogenesis briefly describe the process?',
#  'What is the name of the function of the following?',
#  'What cells produce and?',
#  'What hormones regulate menstrual cycle?',
#  'What is the structure which provides?',
#  'What is oogenesis?',
#  'What is spermatogenesis briefly describe the process of spermatogenesis?',
#  'What is spermatogenesis?',
#  'What happens during pregnancy?',
#  'What is not a reliable indicator of virginity or sexual experience?',
#  'What hormone induces ovulation?',
#  'What type of cells produce androgens?',
#  'Where does oogenesis take place?',
#  'What type of cells are found in ovary?',
#  'How many eggs?',
#  'What are the hormones involved in regulation of spermatogenesis?',
#  'What is the fusion of male and female gametes called?',
#  'What hormones are involved in induction of parturition?']

# %% [markdown]
# # saved them

# %%
def save_questions_to_file(questions, file_path):
    with open(file_path, 'w', encoding='utf-8') as file:
        for question in questions:
            file.write(question)


output_file_path = 'output_questions.txt'

save_questions_to_file(filtered_questions, output_file_path)

# %% [markdown]
# # For assigning page numbers

# %%
matched_strings = []
for filtered_question in filtered_questions:
    for entry in generated_questions:
        if filtered_question.lower() in entry.lower():
            matched_strings.append(entry)

print(matched_strings)
# Out:
# ['1,What is the reproductive event in humans?\n', '1,What is the male reproductive system located in?\n', '1,Where is the male reproductive?\n', '1,What is the name of the sperms in males?\n', '1,What is the name of the text that includes a pair of testes along with accessory ducts glands?\n', '1,Where is the female reproductive system located?\n', '1,What are the differences between the reproductive events in the male and female?\n', '1,What is the female reproductive system?\n', '1,What is the term for transfer of sperms into the female?\n', '1,Where is the male reproductive system located?\n', '1,What is the female reproductive viviparous?\n', '1,What is the female reproductive system located in?\n', '1,What is the male reproductive system?\n', '1,What is the name of the sperms in females?\n', '1,What is the name of the genital tract insemination?\n', '1,What is the male reproductive viviparous?\n', '1,What does ovum cease to do in women around fifty years?\n', '2,What are interstitial spaces called?\n', '2,What is the male sex accessory duct?\n', '2,What is the reproductive system of males?\n', '2,What are the compartments inside the testis called?\n', '2,What do these ducts store and transport?\n', '2,What is the length of the testis in adults?\n', '2,What are the male sex accessory duct?\n', '2,What is the length of the testis?\n', '2,What is the epididymis called?\n', '2,What is the external opening called?\n', '2,What is the pouch called that helps in maintaining the low temperature of the testes?\n', '2,What does the urethra originate from?\n', '2,What is the normal internal body temperature necessary for spermatogenesis in adults?\n', '2,What do male germ cells undergo?\n', '2,What helps in maintaining the low temperature of the testes?\n', '2,What are the male sex accessory ducts?\n', '2,What is the pouch that the testes are located outside the abdominal cavity within?\n', '2,What is the normal internal body temperature needed for spermatogenesis in adults?\n', '2,What are the male sex accessory ducts called?\n', '2,What is the external opening of the urethra?\n', '2,What is the epididymis located along the posterior surface 27 of each testis?\n', '2,What is the urethra called?\n', '3,What is the enlarged end of penis called?\n', '3,How long is each ovary?\n', '3,What is the fold of skin that covers the enlarged end of penis called?\n', '3,What is the seminal plasma rich in?\n', '3,What is the length of?\n', '3,What glands are secreted by the female reproductive system?\n', '3,What is the male external genitalia?\n', '3,What is the male accessory glands?\n', '3,What is the female reproductive system composed of?\n', '14,What is the female reproductive system composed of?\n', '3,What is the primary female sex organs that produce the female?\n', '3,What is the male external genitalia called?\n', '14,What is the male external genitalia called?\n', '3,What are the primary female sex organs?\n', '3,What is the length of each ovary?\n', '3,What is the secretions of?\n', '3,What are the male accessory glands?\n', '3,What is the length of each?\n', '3,What are the primary female sex organs that produce the female?\n', '3,What glands are included in the male accessory glands?\n', '3,What is the male accessory glands called?\n', '3,What is the inner medulla?\n', '3,What is the fold of skin on the enlarged end of penis called?\n', '4,What is the name of the projections on the edges of the infundibulum called?\n', '4,What is the part closer to the ovary called?\n', '4,What is the length of each fallopian tube?\n', '4,What is the female accessory ducts?\n', '4,What is the name of the part closer to the ovary called?\n', '4,What is the infundibulum called?\n', '4,What is the infundibulum that leads to a wider view of the female reproductive system?\n', '5,What is the birth canal called?\n', '5,What is the hymen often torn during?\n', '5,What is the last part of the oviduct isthmus called?\n', '5,What is often torn during the firs ...

# %%
# New lists to store page numbers and questions
page_numbers = []
questions = []

# Check if each element in filtered_questions is present in generated_questions
for filtered_question in filtered_questions:
    for entry in generated_questions:
        if filtered_question.lower() in entry.lower():
            # Split the entry to extract page number and question
            parts = entry.split(',')
            page_numbers.append(parts[0])
            questions.append(parts[1].strip())

# Save page_numbers and questions to a CSV file
output_csv_path = 'matched_strings_output.csv'
with open(output_csv_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(['Page', 'Question'])  # Header

    # Write the data to the CSV file
    for page, question in zip(page_numbers, questions):
        csv_writer.writerow([page, question])

print(f"Page numbers and questions have been saved to '{output_csv_path}'.")
# Out:
# Page numbers and questions have been saved to 'matched_strings_output.csv'.

# %% [markdown]
# # Answer Generation

# %%
from transformers import AutoTokenizer, AutoModelForQuestionAnswering
import torch

# Load model and tokenizer
tokenizer = AutoTokenizer.from_pretrained("susindhar/aiproject-bert-qa")
model = AutoModelForQuestionAnswering.from_pretrained("susindhar/aiproject-bert-qa", from_tf=True)

# Your question
question = "What is the term for transfer of sperms into the female?"

# Your context
context = "chapter 2 human reproduction 2.1 the male reproductive system as you are aware humans are sexually reproducing and 2.2 the female reproductive viviparous. the reproductive events in humans include system formation of gametes gametogenesis i.e. sperms in males 2.3 gametogenesis and ovum in females transfer of sperms into the female 2.4 menstrual cycle genital tract insemination and fusion of male and female gametes fertilisation leading to formation of zygote. this 2.5 fertilisation and is followed by formation and development of blastocyst implantation and its attachment to the uterine wall implantation 2.6 pregnancy and embryonic embryonic development gestation and delivery of the development baby parturition. you have learnt that these reproductive events occur after puberty. there are remarkable 2.7 parturition and lactation differences between the reproductive events in the male and in the female for example sperm formation continues even in old men but formation of ovum ceases in women around the age of fifty years. let us examine the male and female reproductive systems in human. 2.1 t m r s he ale eproductive ystem the male reproductive system is located in the pelvis region figure 2.1a. it includes a pair of testes alongwith accessory ducts glands and the external genitalia. rationalised 202324"

# Tokenize input
inputs = tokenizer(question, context, return_tensors="pt")

# Get the predicted answer
outputs = model(**inputs)

# Extract the start and end scores from the model outputs
answer_start_scores = outputs.start_logits
answer_end_scores = outputs.end_logits

# Convert to PyTorch tensors
answer_start_scores = torch.tensor(answer_start_scores)
answer_end_scores = torch.tensor(answer_end_scores)

# Get the indices of the maximum values
answer_start = torch.argmax(answer_start_scores)
answer_end = torch.argmax(answer_end_scores) + 1

answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(inputs["input_ids"][0][answer_start:answer_end]))

print("Answer:", answer)
# Out:
# All TF 2.0 model weights were used when initializing DistilBertForQuestionAnswering.
#
# All the weights of DistilBertForQuestionAnswering were initialized from the TF 2.0 model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use DistilBertForQuestionAnswering for predictions without further training.
# Answer: ovum
# C:\Users\sriyo\AppData\Local\Temp\ipykernel_10292\2712397496.py:25: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   answer_start_scores = torch.tensor(answer_start_scores)
# C:\Users\sriyo\AppData\Local\Temp\ipykernel_10292\2712397496.py:26: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   answer_end_scores = torch.tensor(answer_end_scores)

# %%
answer
# Out:
# 'ovum'
